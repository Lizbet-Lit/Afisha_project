# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Привет, Елизавета!</b>
#
# Меня зовут Дмитрий Михаленко, я буду ревьюером твоего проекта. Если ты не против, то предлагаю построить наше общение на "ты" ;) Если удобнее на "вы", то нет проблем, только скажи об этом.
#
# Ниже в работе ты найдешь мои комментарии - **пожалуйста, не перемещай, не изменяй и не удаляй их**.
#
# Для наглядности я буду использовать цветовую разметку:
# <font color='green'>зеленого</font>, <font color='gold'>желтого</font> и <font color='red'>красного</font> цветов. Сейчас объясню, что они значат:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Решение на этом шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Решение на этом шаге может стать еще лучше, если внести небольшие коррективы.
# Но настаивать я не буду.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Для правильного решения задачи на этом шаге необходимо внести правки. Напоминаю, что проект не может быть принят, без их отработки.
# </div>
#
# Для продуктивной работы прошу: **если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом**
# Мне будет легче отследить изменения, если ты тоже выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарий студента:</b> Коментарии учла</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
#
# Увидев у тебя ошибку, в первый раз я лишь укажу на ее наличие и дам тебе возможность самостоятельно найти и исправить ее. На реальной работе твой начальник будет поступать так же, а я пытаюсь подготовить тебя именно к работе аналитиком. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Елизавета, очень многое удалось улучшить, молодец! Осталась еще лишь пара моментов, требующих твоего внимания. Уверен, что они не отнимут у тебя много времени!

# %% [markdown]
# # Анализ лояльности пользователей Яндекс Афиши
#
# - Автор: Литау Елизавета
# - Дата:21.09.2026

# %% [markdown]
# # Цели и задачи проекта
#
# <font color='#777778'>  Провести исследовательский анализ лояльности пользователей Яндекс Афиши для лучшего понимания какие пользователи с большей вероятностью возвращаются на платформу и делают заказы повторно, это позволит:
# - быстро выявлять перспективных клиентов и предлагать им персонализированные условия;
# - точно настраивать рекламу на аудитории с высокой вероятностью возврата;
# - оптимизировать маркетинговые бюджеты;
# - повысить общий уровень удержания клиентов;</font>

# %% [markdown]
# # Содержимое проекта
# 1. Этапы выполнения проекта
# 1.1.Загрузка данных и их предобработка
# 1.2 Предобработка данных
# 1.3 Типы данных
# 1.4 Дубликаты
# 1.5 Пропуски
# 1.6 Статистические показатели
# 2. Создание профиля показателей
# 2.1 Исследовательский анализ

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Елизавета, похвально, что не забываешь об оформлении вводной части. В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта! Качественное введение = первое приятное впечатление руководителя о твоей работе)

# %% [markdown]
# ## Этапы выполнения проекта
#
# ### Загрузка данных и их предобработка
#
# ---
#
# **Задача 1.1:** Напишите SQL-запрос, выгружающий в датафрейм pandas необходимые данные. Используйте следующие параметры для подключения к базе данных `data-analyst-afisha`:
#
# - **Хост** — `rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net`
# - **База данных** — `data-analyst-afisha`
# - **Порт** — `6432`
# - **Аутентификация** — `Database Native`
# - **Пользователь** — `praktikum_student`
# - **Пароль** — `Sdf4$2;d-d30pp`
#
# Для выгрузки используйте запрос из предыдущего урока и библиотеку SQLAlchemy.
#
# Выгрузка из базы данных SQL должна позволить собрать следующие данные:
#
# - `user_id` — уникальный идентификатор пользователя, совершившего заказ;
# - `device_type_canonical` — тип устройства, с которого был оформлен заказ (`mobile` — мобильные устройства, `desktop` — стационарные);
# - `order_id` — уникальный идентификатор заказа;
# - `order_dt` — дата создания заказа (используйте данные `created_dt_msk`);
# - `order_ts` — дата и время создания заказа (используйте данные `created_ts_msk`);
# - `currency_code` — валюта оплаты;
# - `revenue` — выручка от заказа;
# - `tickets_count` — количество купленных билетов;
# - `days_since_prev` — количество дней от предыдущей покупки пользователя, для пользователей с одной покупкой — значение пропущено;
# - `event_id` — уникальный идентификатор мероприятия;
# - `service_name` — название билетного оператора;
# - `event_type_main` — основной тип мероприятия (театральная постановка, концерт и так далее);
# - `region_name` — название региона, в котором прошло мероприятие;
# - `city_name` — название города, в котором прошло мероприятие.
#
# ---

# %%
# !pip install sqlalchemy

# %%
# !pip install psycopg2-binary

# %%
import pandas as pd
from sqlalchemy import create_engine 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install phik -q
import phik

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Если добавлять `-q` к загрузке, то логи выводиться не будут) Например:
#
# `!pip install phik -q`
#
# А еще можно устанавливать библиотеки через `try-except`, чтобы лишний раз не прогружать окружение. Подробнее про конструкцию можно почитать [тут](https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html)

# %%
db_config = {'user': 'praktikum_student', # имя пользователя
             'pwd': 'Sdf4$2;d-d30pp', # пароль
             'host': 'rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net',
             'port': 6432, # порт подключения
             'db': 'data-analyst-afisha' # название базы данных
             }

# %%
connection_string = "postgresql://praktikum_student:Sdf4$2;d-d30pp@rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net:6432/data-analyst-afisha"

# %%
connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
    db_config['user'],
    db_config['pwd'],
    db_config['host'],
    db_config['port'],
    db_config['db'],
)

# %%
engine = create_engine(connection_string)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Библиотеки импортировали, коннектор сделали, можем приступать к решению поставленной задачи

# %%
    query = '''
   SELECT 
     p.user_id,
     p.device_type_canonical,
     p.order_id,
     p.created_dt_msk AS order_dt,
     p.created_ts_msk AS order_ts,
     p.currency_code,
     p.revenue,
     p.tickets_count,
     p.created_dt_msk::date - LAG(created_dt_msk) OVER(PARTITION BY user_id ORDER BY created_dt_msk)::date AS days_since_prev,
     p.event_id,
     e.event_name_code AS event_name,
     e.event_type_main,
     service_name,
     r.region_name,
     c.city_name
FROM afisha.purchases p 
INNER JOIN afisha.events e USING(event_id)
LEFT JOIN afisha.city c USING(city_id)
LEFT JOIN afisha.regions r USING(region_id)
WHERE device_type_canonical IN ('mobile','desktop') AND e.event_type_main != 'фильм'
ORDER BY p.user_id
'''

# %%
df = pd.read_sql_query(query, con=engine)

# %%
# 1. Сортируем данные по пользователю и времени.
df = df.sort_values(by=['user_id', 'order_ts'])

# 2. Считаем разницу во времени между текущей строкой и предыдущей строкой ВНУТРИ группы пользователя.
time_diff = df.groupby('user_id')['order_ts'].diff()

# 3. Переводим Timedelta в количество дней (float).
df['days_since_prev'] = time_diff.dt.days

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 290611 entries, 0 to 290610
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name             290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  service_name           290611 non-null  object
#  13  region_name            290611 non-null  object
# ...

# %% [markdown]
# Промежуточный вывод:
#
# Данные выгружены в полном объеме: 14 столбцов, и 1 столбец 'days_since_prev' создан по результатам расчета.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Елизавета, обращаю твое внимание на то, что в запросе необходимо также определять время между заказами для каждого пользователя, а фильтр применять именно по исключению "фильмов" (на русском языке). Предлагаю еще раз перепроверить этот момент, а также скорректировать все дальнейшие пункты работы. Чтобы тебе было проще, могу показать, например, подобный вариант реализации запроса здесь:
#
#
#     query = """
#     SELECT user_id,
#       device_type_canonical,
#       order_id,
#       created_dt_msk AS order_dt,
#       created_ts_msk AS order_ts,
#       currency_code,
#       revenue,
#       tickets_count,
#       created_dt_msk::date - LAG(created_dt_msk) OVER(PARTITION BY user_id ORDER BY created_dt_msk)::date AS days_since_prev,
#       event_id,
#       e.event_name_code AS event_name,
#       e.event_type_main,
#       service_name,
#       r.region_name,
#       c.city_name
#     FROM afisha.purchases p
#     INNER JOIN afisha.events e USING(event_id)
#     LEFT JOIN afisha.city c USING(city_id)
#     LEFT JOIN afisha.regions r USING(region_id)
#     WHERE device_type_canonical IN ('mobile','desktop') AND e.event_type_main != 'фильм'
#     ORDER BY user_id
#     """

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Можно немного улучшить запрос, добавив также и "ORDER BY order_dt". Так внутри каждого пользователя заказы будут идти строго по дате. Дополнительно отмечу, что всегда мы стремимся к презентабельности и наглядности любого проекта. Как следствие напомню,что, например, ресурс https://sqlformat.org/ автоматически преобразует написанный SQL-запрос в унифицированный формат в зависимости от выбранного диалекта SQL, это помогает придать запросу более презентабельный вид и повышает его читабельность.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div> исправила

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Учтено

# %% [markdown]
# ---
#
# **Задача 1.2:** Изучите общую информацию о выгруженных данных. Оцените корректность выгрузки и объём полученных данных.
#
# Предположите, какие шаги необходимо сделать на стадии предобработки данных — например, скорректировать типы данных.
#
# Зафиксируйте основную информацию о данных в кратком промежуточном выводе.
#
# ---

# %%
df.head()
# Out:
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0002849b70a3ce2                mobile   4359165 2024-08-20
# 1  0005ca5e93f2cf4                mobile   7965605 2024-07-23
# 2  0005ca5e93f2cf4                mobile   7292370 2024-10-06
# 3  000898990054619                mobile   1139875 2024-07-13
# 4  000898990054619                mobile    972400 2024-10-04
#
#              order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 0 2024-08-20 16:08:03           rub  1521.94              4              NaN
# 1 2024-07-23 18:36:24           rub   289.45              2              NaN
# 2 2024-10-06 13:56:02           rub  1258.57              4             74.0
# 3 2024-07-13 19:40:48           rub     8.49              2              NaN
# 4 2024-10-04 22:33:15           rub  1390.41              3             83.0
#
#    event_id                            event_name event_type_main  \
# ...

# %%
print(df.columns.tolist())
# Out:
# ['user_id', 'device_type_canonical', 'order_id', 'order_dt', 'order_ts', 'currency_code', 'revenue', 'tickets_count', 'days_since_prev', 'event_id', 'event_name', 'event_type_main', 'service_name', 'region_name', 'city_name']

# %% [markdown]
# Типы данных соответсвуют содержимому колонок.

# %% [markdown]
# - Размер таблицы: количество строк  290611 (из первоначальных 292034 колонка "device_type_canonical"  отфильтрованы по 'mobile' и 'desktop', колонка event_type_main  - по  'movie'), столбцов 14, для анализа этого вполне достаточно.
# - Столбец  "days_since_prev" содержит значения NaN, оставляем как есть, так как это нормальная ситуация, что для первой покупки нет информации по времени от предыдущей покупки.
# - Столбец "currency_code" показывает,что данные в столбце "revenue" российских рублях и казахстанских тенге, неоьходимо привести выручку к единой валюте — российскому рублю.
# - Проверить уникальность идентификаторов. Например, order_id должен быть уникальным (без дублей). Если дубли есть — это может означать ошибку выгрузки или особенность данных, которую нужно прояснить.
# - Посмотреть статистику по числовым колонкам (через describe()). Это поможет выявить аномалии: например, если в revenue есть отрицательные значения или в tickets_count — нецелые числа.
# - Проверить категориальные колонки (например, device_type_canonical, currency_code). Убедится, что значения соответствуют ожидаемым (например, только mobile и desktop в типе устройства). Если есть неожиданные значения (вроде tablet или опечатки), это тоже нужно учесть.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Первичный анализ данных выполнен, намечены шаги по их обработке. В целом, данные у нас достаточно неплохого качества, но можно рассмотреть вариант понижения разрядности для отдельных столбцов. В реальной практике это иногда бывает очень полезным) Предлагаю еще раз скорректировать все выводы здесь и далее после доработки проекта, т.к. они могут претерпеть некоторые изменения

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Елизавета, обращаю твое внимание здесь на один важный момент: пропуски в `days_since_prev` лучше оставлять как есть, так как это нормальная ситуация, что для первой покупки нет информации по времени от предыдущей покупки.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div> исправила

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Учтено

# %% [markdown]
# ---
#
# ###  Предобработка данных. Конвертация валюты
#
# Выполните все стандартные действия по предобработке данных:
#
# ---
#
# **Задача 2.1:** Данные о выручке сервиса представлены в российских рублях и казахстанских тенге. Приведите выручку к единой валюте — российскому рублю.
#
# Для этого используйте датасет с информацией о курсе казахстанского тенге по отношению к российскому рублю за 2024 год — `final_tickets_tenge_df.csv`. Его можно загрузить по пути `https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')`
#
# Значения в рублях представлено для 100 тенге.
#
# Результаты преобразования сохраните в новый столбец `revenue_rub`.
#
# ---

# %%
# Загрузка информацией о курсе казахстанского тенге по отношению к российскому рублю за 2024 год
url = 'https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv'
rates = pd.read_csv(url)

# %%
rates.head()
# Out:
#          data  nominal     curs  cdx
# 0  2024-01-10      100  19.9391  kzt
# 1  2024-01-11      100  19.7255  kzt
# 2  2024-01-12      100  19.5839  kzt
# 3  2024-01-13      100  19.4501  kzt
# 4  2024-01-14      100  19.4501  kzt

# %%
rates = rates.rename(columns={'data': 'date'})
rates['date'] = pd.to_datetime(rates['date'])

# В основном датасете берём колонку created_dt_msk и тоже делаем её датой
df['date'] = pd.to_datetime(df['order_dt'])

# Объединяем таблицы по дате
# left join: берём все строки из df (продаж) и ищем к ним курс по дате
merged = pd.merge(df, rates, on='date', how='left')

#Считаем выручку в рублях
# Создаём столбец и сразу заполняем его нулями или копируем revenue (как базу)
merged['revenue_rub'] = merged['revenue']

# Теперь перезаписываем только те строки, где валюта KZT
# Формула: выручка * (курс / 100)
mask_kzt = merged['currency_code'] == 'KZT'
merged.loc[mask_kzt, 'revenue_rub'] = merged.loc[mask_kzt, 'revenue'] * (merged.loc[mask_kzt, 'curs'] / 100)

# %%
# Посмотрим на статистику нового столбца
print(merged['revenue_rub'].describe())

# Проверим, не осталось ли NaN там, где не должно быть
# Например, если у нас был KZT, но не было курса (curs = NaN), то revenue_rub тоже станет NaN
print(merged[merged['currency_code'] == 'KZT']['revenue_rub'].isna().sum())
# Out:
# count    290611.000000
# mean        625.584360
# std        1227.693064
# min         -90.760000
# 25%         116.850000
# 50%         356.010000
# 75%         810.130000
# max       81174.540000
# Name: revenue_rub, dtype: float64
# 0

# %%
# Находим аномальные строки
anomalies = merged[merged['revenue_rub'] < 0]

# Смотрим, сколько их всего
print(f"Количество транзакций с отрицательной выручкой: {len(anomalies)}")

# Выводим первые 5 строк, чтобы глазами глянуть на детали
anomalies.head()
# Out:
# Количество транзакций с отрицательной выручкой: 381
#               user_id device_type_canonical  order_id   order_dt  \
# 252   00eb3dc9baa1543                mobile   1594653 2024-06-29
# 4536  02ea4583333f064                mobile   2360920 2024-09-03
# 4549  02ea4583333f064                mobile   2361094 2024-09-04
# 8134  043f669c9f734b1                mobile    166780 2024-09-27
# 8135  043f669c9f734b1                mobile    166809 2024-09-27
#
#                 order_ts currency_code  revenue  tickets_count  \
# 252  2024-06-29 15:01:43           rub    -2.37              3
# 4536 2024-09-03 18:12:58           rub    -0.23              3
# 4549 2024-09-04 09:34:53           rub    -0.15              2
# 8134 2024-09-27 10:00:09           rub    -1.86              3
# 8135 2024-09-27 10:56:35           rub    -0.62              1
#
#       days_since_prev  event_id                            event_name  \
# ...

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b>  Методы `.head()` и `.info()` можно применять без `.print()`. Так таблицы будут представлены в более читабельном формате, а не в виде текста)

# %%
# Ищем строки, где и выручка < 0, И количество билетов < 0
refunds_check = merged[(merged['revenue_rub'] < 0) & (merged['tickets_count'] < 0)]
print(f"Строк с отрицательной выручкой И отрицательным количеством билетов: {len(refunds_check)}")
refunds_check[['revenue_rub', 'tickets_count', 'currency_code']].head()
# Out:
# Строк с отрицательной выручкой И отрицательным количеством билетов: 0
# Empty DataFrame
# Columns: [revenue_rub, tickets_count, currency_code]
# Index: []

# %%
anomalies = merged[merged['revenue_rub'] < 0]
print(anomalies['revenue_rub'].describe())
print("\nСамые частые значения отрицательной выручки:")
anomalies['revenue_rub'].value_counts().head(10)
# Out:
# count    381.000000
# mean      -2.492362
# std        5.065072
# min      -90.760000
# 25%       -3.450000
# 50%       -1.580000
# 75%       -0.650000
# max       -0.010000
# Name: revenue_rub, dtype: float64
#
# Самые частые значения отрицательной выручки:
# -3.59    18
# -1.38    16
# -0.15    14
# -4.15    13
# -0.23    13
# -2.77    11
# -7.18    10
# -2.37    10
# -3.52    10
# -0.79     9
# Name: revenue_rub, dtype: int64

# %%
# Создаём признак: 'sale' (продажа), 'adjustment' (корректировка/возврат) или 'other'
def classify_transaction(row):
    if row['revenue_rub'] > 0:
        return 'sale'
    elif row['revenue_rub'] <= 0:
        # Учитывая, что у нас нет отрицательных билетов, считаем всё с минусом корректировками
        return 'adjustment'
    else:
        return 'other'

merged['transaction_type'] = merged.apply(classify_transaction, axis=1)

# Проверяем, сколько чего получилось
print(merged['transaction_type'].value_counts())
# Out:
# sale          284704
# adjustment      5907
# Name: transaction_type, dtype: int64

# %%
# 1. Создаем копию исходного датасета
clean_df = df.copy()

# 2. Добавляем колонку
clean_df['revenue_rub'] = merged['revenue_rub']

# Удаляем колонку 'date', она больше не нужна
clean_df = clean_df.drop(columns=['date'])

# Проверяем, что получилось
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 290611 entries, 0 to 290610
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name             290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  service_name           290611 non-null  object
#  13  region_name            290611 non-null  object
# ...

# %% [markdown]
# #### Промежуточный вывод по транзакци
# При транзакции создан столбец revenue_rub и выявленны отрицательные суммы, количество транзакций с отрицательной выручкой: 381. Данные принято не удалять.
# Всего продаж "sale" на сумму 285881,
# из них отрицательных операций "adjustment" на сумму 6153

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Выручка приведена к единой валюте

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Здорово, что отмечаешь наличие отрицательных значений в наших данных и считаешь их количество. В качестве рекомендации, здесь можно их сразу удалить. В будущих подобных проектах может быть ситуация, когда их будет не единичное количество, а скажем, десятки процентов из-за ошибки в записи. Понятно, что по графикам видно, что их не много, и идет контроль удаленных значений, но лучше сразу все предусматривать)

# %% [markdown]
# **Задача 2.2:**
#
# - Проверьте данные на пропущенные значения. Если выгрузка из SQL была успешной, то пропуски должны быть только в столбце `days_since_prev`.
#
# - Изучите значения в ключевых столбцах. Обработайте ошибки, если обнаружите их.
#     - Проверьте, какие категории указаны в столбцах с номинальными данными. Есть ли среди категорий такие, что обозначают пропуски в данных или отсутствие информации? Проведите нормализацию данных, если это необходимо.
#     - Проверьте распределение численных данных и наличие в них выбросов. Для этого используйте статистические показатели, гистограммы распределения значений или диаграммы размаха.
#
#         Важные показатели в рамках поставленной задачи — это выручка с заказа (`revenue_rub`) и количество билетов в заказе (`tickets_count`), поэтому в первую очередь проверьте данные в этих столбцах.
#
#         Если обнаружите выбросы в поле `revenue_rub`, то отфильтруйте значения по 99 перцентилю.
#
# После предобработки проверьте, были ли отфильтрованы данные. Если были, то оцените, в каком объёме. Сформулируйте промежуточный вывод, зафиксировав основные действия и описания новых столбцов.
#
# ---

# %% [markdown]
# ### Типы данных
# - Преобразуйте типы данных в некоторых столбцах, если это необходимо. Обратите внимание на данные с датой и временем, а также на числовые данные, размерность которых можно сократить.

# %%
# 1. Оптимизация числовых колонок с маленькими целыми числами
clean_df['tickets_count'] = clean_df['tickets_count'].astype('int8')

# 2. Оптимизация текстовых колонок через тип 'category'
categorical_cols = [
    'device_type_canonical', 
    'currency_code', 
    'event_type_main', 
    'service_name',
    'city_name',
    'region_name'
]

for col in categorical_cols:
    # Проверяем, есть ли колонка в датасете, чтобы не было ошибки
    if col in clean_df.columns:
        clean_df[col] = clean_df[col].astype('category')

# 3. Проверка результата
print("Оптимизированный датасет:")
print(clean_df.info(memory_usage='deep'))
# Out:
# Оптимизированный датасет:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 290611 entries, 0 to 290610
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  category
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  category
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int8
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name             290611 non-null  object
#  11  event_type_main        290611 non-null  category
#  12  service_name           290611 non-null  category
# ...

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Для будущих твоих проектов могу отметить, что если нет острой необходимости, то лучше не переводить в категориальный тип. Этот тип все же нужен не везде, где есть категории, а где нужна их последовательность, ранжирование и нужны все значения.

# %% [markdown]
# ### Дубликаты

# %%
unique_order_count = df['order_id'].nunique()

total_rows = len(df)

print(f"Всего строк в таблице: {total_rows}")
print(f"Уникальных order_id:    {unique_order_count}")

# Логическая проверка
if total_rows == unique_order_count:
    print("Все order_id уникальны. Дубликатов нет.")
    print("   (Это значит, что 1 строка = 1 заказ)")
else:
    duplicates = total_rows - unique_order_count
    print(f"Внимание! Найдено дубликатов заказов: {duplicates}")
    print(f"   (Строк: {total_rows}, Уникальных ID: {unique_order_count})")
# Out:
# Всего строк в таблице: 290611
# Уникальных order_id:    290611
# Все order_id уникальны. Дубликатов нет.
#    (Это значит, что 1 строка = 1 заказ)

# %%
# Проверяем наличие неявных дубликатов - используем время покупки
columns_to_dupl = ['user_id', 'order_ts', 'device_type_canonical',
'service_name', 'event_id', 'revenue']
df[columns_to_dupl].duplicated().sum()

# Для контроля выводим несколько неявных дубликатов 
df[df[columns_to_dupl].duplicated(keep=False)].head(6)
# Out:
#                user_id device_type_canonical  order_id   order_dt  \
# 11758  06eb7897f65b433                mobile   1123867 2024-08-13
# 11761  06eb7897f65b433                mobile   1123983 2024-08-13
# 26876  0dc525d7bacbb0d               desktop   1930705 2024-07-31
# 26877  0dc525d7bacbb0d               desktop   1930763 2024-07-31
# 53681  206ea45ec11d478                mobile   1935113 2024-10-29
# 53682  206ea45ec11d478                mobile   1935171 2024-10-29
#
#                  order_ts currency_code  revenue  tickets_count  \
# 11758 2024-08-13 16:31:07           rub    69.82              1
# 11761 2024-08-13 16:31:07           rub    69.82              1
# 26876 2024-07-31 13:26:11           rub  1556.05              3
# 26877 2024-07-31 13:26:11           rub  1556.05              3
# 53681 2024-10-29 16:46:54           rub   601.69              2
# 53682 2024-10-29 16:46:54           rub   601.69              2
#
# ...

# %%
# Удаляем дубликаты, оставляя первую встреченную строку
df = df.drop_duplicates(subset=columns_to_dupl, keep='first')

# %%
print(f"После удаления: {len(df)}")
# Out:
# После удаления: 290569

# %%
df[columns_to_dupl].duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Елизавета, явные дубли ты проверила, молодец. Но все же стоит проверить здесь и наличие неявных дубликатов, проведя анализ категориальных столбцов нашего датасета. Начать можно с проверки уникальных значений, возможно они потребуют некоторых преобразований (приведения к одному регистру и т.п.). Также стоит проверить неявные дубликаты и по времени покупки, например, так:
#
#     # Проверяем наличие неявных дубликатов - используем время покупки
#     columns_to_dupl = ['user_id', 'order_ts', 'device_type_canonical',
#     'service_name', 'event_id', 'revenue']
#     df[columns_to_dupl].duplicated().sum()
#
#     # Для контроля выводим несколько неявных дубликатов
#     df[df[columns_to_dupl].duplicated(keep=False)].head(6)
#
# Будет заметно, что полные дубликаты строк все же присутствуют, хотя номера заказов разные. Необходимо убедиться, что их доля малая и удалить. Тогда вопрос по неявным дублям будет рассмотрен исчерпывающе

# %% [markdown]
# Проверка на неявные дубликаты показала лишние 42 строки, они - удалены

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Совершенно верно

# %% [markdown]
# ### Пропуски
# - Проверьте, какие категории указаны в столбцах с номинальными данными. Есть ли среди категорий такие, что обозначают пропуски в данных или отсутствие информации? Проведите нормализацию данных, если это необходимо.

# %%
print(clean_df.isnull().sum())
# Out:
# user_id                      0
# device_type_canonical        0
# order_id                     0
# order_dt                     0
# order_ts                     0
# currency_code                0
# revenue                      0
# tickets_count                0
# days_since_prev          21933
# event_id                     0
# event_name                   0
# event_type_main              0
# service_name                 0
# region_name                  0
# city_name                    0
# revenue_rub                  0
# dtype: int64

# %% [markdown]
# Пропуски в столбце оставляем как есть чтобы не искажать статистику

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Абсолютно верно

# %% [markdown]
# ### Статистические показатели
# - Проверьте распределение численных данных и наличие в них выбросов. Для этого используйте статистические показатели, гистограммы распределения значений или диаграммы размаха.

# %%
# Выбираем только самые важные числовые колонки для проверки на аномалии
cols_to_check = ['revenue_rub', 'tickets_count', 'days_since_prev']

# Получаем статистику
stats = clean_df[cols_to_check].describe()

# Выводим красиво
print("Статистика по ключевым числовым колонкам:")
print(stats)
# Out:
# Статистика по ключевым числовым колонкам:
#          revenue_rub  tickets_count  days_since_prev
# count  290611.000000  290611.000000    268678.000000
# mean      625.584360       2.754311         3.028063
# std      1227.693064       1.170620        11.261415
# min       -90.760000       1.000000         0.000000
# 25%       116.850000       2.000000         0.000000
# 50%       356.010000       3.000000         0.000000
# 75%       810.130000       4.000000         0.000000
# max     81174.540000      57.000000       148.000000

# %%
plt.figure(figsize=(15, 5))

for i, col in enumerate(cols_to_check):
    plt.subplot(1, 3, i+1)
    # showfliers=True показывает точки-выбросы явно
    clean_df.boxplot(column=[col], grid=False, showfliers=True) 
    plt.title(f'Boxplot: {col}')
    plt.ylabel(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Елизавета, обрати внимание, согласно ТЗ: `Проверьте распределение численных данных и наличие в них выбросов. Для этого используйте статистические показатели, гистограммы распределения значений или диаграммы размаха.` Стоит здесь также представить соответствующие гистограммы, а также боксплоты для наглядности

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Учтено

# %%
threshold = 10000

# Считаем количество заказов выше порога
count_high = clean_df[clean_df['revenue_rub'] > threshold].shape[0]

# Считаем общее количество заказов
total_count = clean_df.shape[0]

# Считаем процент
percentage = (count_high / total_count) * 100

print(f"Заказов дороже {threshold} руб.: {count_high}")
print(f"Это составляет {percentage:.4f}% от всех заказов")
# Out:
# Заказов дороже 10000 руб.: 926
# Это составляет 0.3186% от всех заказов

# %%
# Считаем 99-й перцентиль для колонки revenue_rub
p99 = clean_df['revenue_rub'].quantile(0.99)
print(f"99-й перцентиль выручки: {p99:.2f} руб.")
# Out:
# 99-й перцентиль выручки: 4003.13 руб.

# %%
# Выбираем заказы, которые попали в тот самый 1% самых дорогих
expensive_orders = clean_df[clean_df['revenue_rub'] > p99]

# Посмотрим на первые 10 таких заказов, чтобы понять, что там происходит
print("Примеры самых дорогих заказов:")
print(expensive_orders[['order_id', 'user_id', 'revenue_rub', 'tickets_count', 'event_name']].head(10))

# И сразу посчитаем статистику именно по этим дорогим заказам
print("\nСтатистика по дорогим заказам (выше 99-го перцентиля):")
print(expensive_orders['revenue_rub'].describe())
# Out:
# Примеры самых дорогих заказов:
#       order_id          user_id  revenue_rub  tickets_count  \
# 277     720419  00f4f5244501ce6     22021.55              5
# 462    2229782  01370a0e9c1a7d5      7397.66              2
# 461    2229811  01370a0e9c1a7d5      7397.66              4
# 464    2229724  01370a0e9c1a7d5      7397.66              4
# 463    2229753  01370a0e9c1a7d5      5548.24              3
# 809    4451269  019fa401ddb00aa     22021.55              5
# 899    2071181  019fa401ddb00aa      4328.68              2
# 1522   4944530  01db97121ed5e19      5548.24              3
# 1626   4243977  0204ecbadbe6616      6892.13              2
# 1625   4244006  0204ecbadbe6616      6892.13              2
#
#                                 event_name
# 277   76af4f88-c554-4e9e-9df4-1cc8aeec8959
# 462   0686ac7b-6f3e-4177-bb73-16b54acd1223
# 461   0686ac7b-6f3e-4177-bb73-16b54acd1223
# 464   0686ac7b-6f3e-4177-bb73-16b54acd1223
# 463   0686ac7b-6f3e-4177-bb73-16b54acd1223
# ...

# %%
# Сортируем дорогие заказы по выручке по убыванию и берем топ-5
top_expensive = expensive_orders.sort_values(by='revenue_rub', ascending=False).head(5)

# Выводим ключевые колонки для проверки
cols_to_show = ['order_id', 'user_id', 'revenue_rub', 'tickets_count', 'event_name', 'event_type_main']
print(top_expensive[cols_to_show])
# Out:
#         order_id          user_id  revenue_rub  tickets_count  \
# 183750    535631  96368e5714d1673     81174.54              3
# 122337   4113477  5b5714894bd0517     81174.54              5
# 122338   4113506  5b5714894bd0517     81174.54              4
# 111506   8330309  5245e419c5ac876     64939.63              4
# 122336   4113535  5b5714894bd0517     64939.63              5
#
#                                   event_name event_type_main
# 183750  3410a081-a0e3-4263-a54f-d830f5a084da        концерты
# 122337  b443dc5a-fff2-4b69-8684-0719fff49b59        концерты
# 122338  b443dc5a-fff2-4b69-8684-0719fff49b59        концерты
# 111506  b443dc5a-fff2-4b69-8684-0719fff49b59        концерты
# 122336  b443dc5a-fff2-4b69-8684-0719fff49b59        концерты

# %% [markdown]
# Для выявления аномалий в выручке (revenue_rub) был рассчитан 99‑й перцентиль, который составил 4003.13 руб. В верхнюю 1% выборки попало 2907 заказов.
# Детальный анализ этой выборки показал, что высокие значения выручки обусловлены бизнес-логикой площадки, а не ошибками ввода данных:
# Пакетные покупки и VIP-сегмент. Например, заказ №535631 (пользователь 96368e57...) на сумму 81 174 руб. включает покупку 3 билетов. Средняя стоимость билета в этом заказе составляет ~27 000 руб., что соответствует ценам на топовые места (VIP-ложи) на концертах. Аналогичная ситуация наблюдается в серии заказов пользователя 5b571489..., где суммы 81 174 руб. и 64 939 руб. также объясняются покупкой 4–5 дорогих билетов.
# Специфика мероприятий. Все экстремальные значения приходятся на категорию «концерты», что логично, так как билеты на массовые зрелищные мероприятия традиционно стоят дороже, чем на лекции или спектакли.
# Поведение лояльных клиентов. В выборке выявлены пользователи, совершающие повторные дорогие покупки (например, пользователь 5b571489... сделал 3 заказа в верхнем перцентиле). Удаление таких записей исказило бы анализ поведения высокодоходного сегмента аудитории.
# Решение: Данные признаны валидными и сохранены в датасете. Для дальнейшего анализа целевой переменной эти заказы критически важны, так как отражают поведение наиболее ценных пользователей площадки.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Удобно и вполне обоснованно здесь будет использовать 99-й персентиль при фильтрации выбросов по revenue_rub, как нам и предложено в ТЗ

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Елизавета, этап предобработки данных, в целом, осуществлен, но я оставил несколько рекомендаций по тому, как можно сделать его еще качественнее. В соответствии с этим рекомендовал бы также же дополнить промежуточный вывод результатами, которые получатся после доработки - и тогда все будет идеально

# %% [markdown]
# ---
#
# ##  Создание профиля пользователя
#
# В будущем отдел маркетинга планирует создать модель для прогнозирования возврата пользователей. Поэтому сейчас они просят вас построить агрегированные признаки, описывающие поведение и профиль каждого пользователя.
#
# ---
#
# **Задача 3.1.** Постройте профиль пользователя — для каждого пользователя найдите:
#
# - дату первого и последнего заказа;
# - устройство, с которого был сделан первый заказ;
# - регион, в котором был сделан первый заказ;
# - билетного партнёра, к которому обращались при первом заказе;
# - жанр первого посещённого мероприятия (используйте поле `event_type_main`);
# - общее количество заказов;
# - средняя выручка с одного заказа в рублях;
# - среднее количество билетов в заказе;
# - среднее время между заказами.
#
# После этого добавьте два бинарных признака:
#
# - `is_two` — совершил ли пользователь 2 и более заказа;
# - `is_five` — совершил ли пользователь 5 и более заказов.
#
# **Рекомендация:** перед тем как строить профиль, отсортируйте данные по времени совершения заказа.
#
# ---

# %%
# Сортировка 
# Сортируем по пользователю и по времени заказа
clean_df_sorted = clean_df.sort_values(by=['user_id', 'order_dt'])

# Агрегация количественных метрик (сумма, среднее, количество)
numeric_agg = clean_df_sorted.groupby('user_id').agg(
    total_orders=('order_id', 'count'),        
    avg_revenue=('revenue_rub', 'mean'),       
    avg_tickets=('tickets_count', 'mean')        
).reset_index()

# Агрегация качественных метрик
first_order_features = clean_df_sorted.groupby('user_id').agg(
    first_order_date=('order_dt', 'first'),
    first_device=('device_type_canonical', 'first'),
    first_region=('region_name', 'first'),
    first_partner=('service_name', 'first'),
    first_genre=('event_type_main', 'first')
).reset_index()

# Расчёт среднего времени между заказами
# Берем среднее по колонке days_since_prev. 
# Если у пользователя 1 заказ, там будет NaN
avg_gap = clean_df_sorted.groupby('user_id')['days_since_prev'].mean().reset_index()
avg_gap.rename(columns={'days_since_prev': 'avg_days_between_orders'}, inplace=True)

# Сборка профиля (Merge всех частей)
# Начинаем с числовых данных и присоединяем остальные по user_id
user_profile = numeric_agg.merge(first_order_features, on='user_id')
user_profile = user_profile.merge(avg_gap, on='user_id', how='left')

# Добавление бинарных признаков
# is_two: 1, если заказов >= 2, иначе 0
user_profile['is_two'] = (user_profile['total_orders'] >= 2).astype(int)

# is_five: 1, если заказов >= 5, иначе 0
user_profile['is_five'] = (user_profile['total_orders'] >= 5).astype(int)

# Проверка результата
print(f"Итоговый профиль пользователя содержит {user_profile.shape[0]} строк (пользователей)")
print(user_profile.head())
print("\nСтатистика по новым бинарным признакам:")
print(user_profile[['is_two', 'is_five']].sum())
# Out:
# Итоговый профиль пользователя содержит 21933 строк (пользователей)
#            user_id  total_orders  avg_revenue  avg_tickets first_order_date  \
# 0  0002849b70a3ce2             1  1521.940000     4.000000       2024-08-20
# 1  0005ca5e93f2cf4             2   774.010000     3.000000       2024-07-23
# 2  000898990054619             3   767.213333     2.666667       2024-07-13
# 3  00096d1f542ab2b             1   917.830000     4.000000       2024-08-15
# 4  000a55a418c128c             2    61.310000     1.500000       2024-09-29
#
#   first_device          first_region  first_partner first_genre  \
# 0       mobile    Каменевский регион   Край билетов       театр
# 1       mobile    Каменевский регион      Мой билет    выставки
# 2       mobile  Североярская область    Лови билет!      другое
# 3      desktop    Каменевский регион   Край билетов       театр
# 4       mobile      Поленовский край  Лучшие билеты       театр
#
#    avg_days_between_orders  is_two  is_five
# ...

# %% [markdown]
# ### ВЫВОД
#
# Итоговый профиль пользователя содержит 21933 строк (пользователей);
#
# из них:
# - 13559 пользователей совершили 2 и более заказа;
# - 6400 пользователей совершили 5 и более заказа

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Профиль пользователя собран, добавлены новые признаки.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Дополнительно отмечу, что признаки также можно добавлять сразу при формировании нашего профиля, добавив метод .assign, после основного тела. Покажу и такой пример более рационального формирования нашего профиля здесь:
#
#         # Собираем профиль пользователя:
#         profiles = (df
#             # В начале сортируем данные по дате совершения заказа, что найти первые признаки:
#             .sort_values(by='order_ts')
#             # Затем группируем по номеру пользователя и агрегируем данные:
#             .groupby('user_id')
#             .agg(
#                 # Находим первую и последнюю даты заказа:
#                 first_order_dt=('order_dt','min'),
#                 last_order_dt=('order_dt','max'),
#                 # Находим устройства, регион и название билетного партнера первого заказа:
#                 first_device=('device_type_canonical','first'),
#                 first_region_name=('region_name','first'),
#                 first_service_name=('service_name','first'),
#                 # Жанр первого посещённого мероприятия (event_type_main):
#                 first_event_type=('event_type_main','first'),
#                 # Подсчитваем количество заказов:
#                 total_orders=('order_id','nunique'),
#                 # Считаем статистику по заказам: средняя стоимость заказа, среднее количество билетов:
#                 avg_revenue_rub=('revenue_rub','mean'),
#                 avg_tickets_count=('tickets_count','mean'),
#                 # Считаем среднее количество дней между покупками:
#                 avg_days_since_prev=('days_since_prev','mean')
#             )
#             # Создаем два признака: совершил ли пользователь 2 / 5 и более заказов:
#             .assign(
#                 is_two = lambda x: x['total_orders'] >= 2,
#                 is_five = lambda x: x['total_orders'] >= 5
#             )

# %% [markdown]
# ---
#
# **Задача 3.2.** Прежде чем проводить исследовательский анализ данных и делать выводы, важно понять, с какими данными вы работаете: насколько они репрезентативны и нет ли в них аномалий.
#
# Используя данные о профилях пользователей, рассчитайте:
#
# - общее число пользователей в выборке;
# - среднюю выручку с одного заказа;
# - долю пользователей, совершивших 2 и более заказа;
# - долю пользователей, совершивших 5 и более заказов.
#
# Также изучите статистические показатели:
#
# - по общему числу заказов;
# - по среднему числу билетов в заказе;
# - по среднему количеству дней между покупками.
#
# По результатам оцените данные: достаточно ли их по объёму, есть ли аномальные значения в данных о количестве заказов и среднем количестве билетов?
#
# Если вы найдёте аномальные значения, опишите их и примите обоснованное решение о том, как с ними поступить:
#
# - Оставить и учитывать их при анализе?
# - Отфильтровать данные по какому-то значению, например, по 95-му или 99-му перцентилю?
#
# Если вы проведёте фильтрацию, то вычислите объём отфильтрованных данных и выведите статистические показатели по обновлённому датасету.

# %%
# общее число пользователей в выборке;
total_users = clean_df_sorted['user_id'].nunique()
print(f"Общее число пользователей: {total_users}")
# Out:
# Общее число пользователей: 21933

# %%
# Считаем общую выручку (сумма по колонке, где хранится цена заказа)
total_revenue = clean_df_sorted['revenue'].sum()

# Считаем общее количество заказов (количество строк или уникальных order_id)
total_orders = clean_df_sorted['order_id'].nunique() 
# ИЛИ, если в данных нет дублей заказов: len(clean_df_sorted)

# Делим
avg_revenue_per_order = total_revenue / total_orders
print(f"Средняя выручка с одного заказа: {avg_revenue_per_order:.2f}")
# Out:
# Средняя выручка с одного заказа: 625.58

# %%
#доля пользователей, совершивших 2 и более заказов.
# Число заказов на пользователя
orders_per_user = clean_df_sorted.groupby('user_id')['order_id'].count()
# число пользователей сделавших 2 и более заказов
users_with_2_plus = orders_per_user[orders_per_user >= 2]
# доля пользователей
share_2_plus = len(users_with_2_plus) / len(orders_per_user)
print(f"Доля пользователей, совершивших 2 и более заказа: {share_2_plus:.2f}")
# Out:
# Доля пользователей, совершивших 2 и более заказа: 0.62

# %%
#долю пользователей, совершивших 5 и более заказов.
# Число заказов на пользователя
orders_per_user = clean_df_sorted.groupby('user_id')['order_id'].count()
# число пользователей сделавших 5 и более заказов
users_with_5_plus = orders_per_user[orders_per_user >= 5]
# доля пользователей
share_5_plus = len(users_with_5_plus) / len(orders_per_user)
print(f"Доля пользователей, совершивших 5 и более заказа: {share_5_plus:.2f}")
# Out:
# Доля пользователей, совершивших 5 и более заказа: 0.29

# %%
# Проверяем, что переменная существует (на всякий случай)
if 'user_profile' in globals():
    total_users = user_profile.shape[0]
    print(f"Общее число уникальных пользователей в профиле: {total_users}")
    
    avg_revenue_per_order = total_revenue / total_orders
    print(f"Средняя выручка с одного заказа: {avg_revenue_per_order:.2f}")

    share_2plus = user_profile['is_two'].mean()
    print(f"Доля пользователей с 2+ заказами: {share_2plus:.2%}")

    share_5plus = user_profile['is_five'].mean()
    print(f"Доля пользователей с 5+ заказами: {share_5plus:.2%}")

    count_2plus = user_profile['is_two'].sum()
    count_5plus = user_profile['is_five'].sum()
    print(f"Абсолютное число пользователей с 2+ заказами: {count_2plus}")
    print(f"Абсолютное число пользователей с 5+ заказами: {count_5plus}")
else:
    print("Ошибка: переменная user_profile не найдена! Проверь название переменной, куда ты сохранила результат groupby.")
# Out:
# Общее число уникальных пользователей в профиле: 21933
# Средняя выручка с одного заказа: 625.58
# Доля пользователей с 2+ заказами: 61.82%
# Доля пользователей с 5+ заказами: 29.18%
# Абсолютное число пользователей с 2+ заказами: 13559
# Абсолютное число пользователей с 5+ заказами: 6400

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Можно рассматривать данные , например, и подобной конструкцией:
#
#     # Изучим общее количество пользователей в полученных данных:
#     print(f"Общее число пользователей: {df_1['user_id'].nunique()}")
#     print(f"Было отфильтровано: {1-df_1['user_id'].nunique()/df_1['user_id'].nunique():.2%} пользователей")
#
#     # Подсчитаем долю пользователей, совершивших 2 / 5 и более заказов:
#     print(f"Доля пользователей совершивших 2 и более заказа: {df_1['is_two'].mean():.2f}")
#     print(f"Доля пользователей совершивших 5 и более заказов: {df_1['is_five'].mean():.2f}")

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div> так действительно нагляднее

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Рад помочь советом)

# %%
# статистические показатели:
# Статистика по общему числу заказов (на пользователя)
# Создаем таблицу users_stats: одна строка = один пользователь, колонка total_orders = число его заказов
users_stats = clean_df_sorted.groupby('user_id').size().reset_index(name='total_orders')

print("Статистика по числу заказов на пользователя:")
print(users_stats['total_orders'].describe())
print("-" * 30)

# Статистика по среднему числу билетов в заказе
ticket_col = 'tickets_count' 
print(f"Статистика по количеству билетов в заказе (колонка '{ticket_col}'):")
print(clean_df_sorted[ticket_col].describe())

# Статистика по среднему количеству дней между покупками
# Сортируем данные по пользователю и дате
df_sorted = clean_df_sorted.sort_values(['user_id', 'order_dt'])

# Считаем разницу между текущей и предыдущей покупкой для каждого пользователя
# .diff() посчитает разницу. Для самой первой покупки пользователя будет NaN
df_sorted['days_between'] = df_sorted.groupby('user_id')['order_dt'].diff().dt.days

# Считаем среднее время между покупками пользователя
avg_gap_per_user = df_sorted.groupby('user_id')['days_between'].mean()

print("Статистика по среднему количеству дней между покупками (на пользователя):")
print(avg_gap_per_user.describe())
# Out:
# Статистика по числу заказов на пользователя:
# count    21933.000000
# mean        13.249943
# std        122.470535
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max      10251.000000
# Name: total_orders, dtype: float64
# ------------------------------
# Статистика по количеству билетов в заказе (колонка 'tickets_count'):
# count    290611.000000
# mean          2.754311
# std           1.170620
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max          57.000000
# Name: tickets_count, dtype: float64
# Статистика по среднему количеству дней между покупками (на пользователя):
# count    13559.000000
# mean        15.808537
# std         22.249582
# min          0.000000
# 25%          1.000000
# 50%          8.000000
# 75%         20.400000
# max        148.000000
# Name: days_between, dtype: float64

# %%
# Сортируем по количеству заказов по убыванию и берем топ-10
top_users = users_stats.sort_values(by='total_orders', ascending=False).head(10)

print("Топ-10 пользователей по количеству заказов:")
print(top_users)
# Out:
# Топ-10 пользователей по количеству заказов:
#                user_id  total_orders
# 985    0beb8fc0c0a9ce1         10251
# 2061   18e9aead0a393e7          4368
# 11114  8187dac4be757a0          4053
# 5432   3ee7dc2e115847f          3826
# 10849  7eb4fc207ecc10f          3749
# 2338   1c2a2133e1df1b4          3538
# 6801   4ec8f6429431987          3413
# 14816  ad2dc32364ed948          3275
# 15555  b54dd0cd81121fc          3163
# 17698  cdbc02c6ad8087a          3071

# %%
print("Топ-10 пользователей по количеству заказов:")
print(top_users)

# Посчитаем, сколько всего заказов сделали эти 10 человек
total_orders_top10 = top_users['total_orders'].sum()
total_orders_all = clean_df_sorted['order_id'].nunique() # или count, зависит от структуры

share_top10 = total_orders_top10 / total_orders_all
print(f"\nТоп-10 пользователей совершили {total_orders_top10} заказов.")
print(f"Это составляет {share_top10:.2%} от ВСЕХ заказов в датасете!")
# Out:
# Топ-10 пользователей по количеству заказов:
#                user_id  total_orders
# 985    0beb8fc0c0a9ce1         10251
# 2061   18e9aead0a393e7          4368
# 11114  8187dac4be757a0          4053
# 5432   3ee7dc2e115847f          3826
# 10849  7eb4fc207ecc10f          3749
# 2338   1c2a2133e1df1b4          3538
# 6801   4ec8f6429431987          3413
# 14816  ad2dc32364ed948          3275
# 15555  b54dd0cd81121fc          3163
# 17698  cdbc02c6ad8087a          3071
#
# Топ-10 пользователей совершили 42707 заказов.
# Это составляет 14.70% от ВСЕХ заказов в датасете!

# %%
# Считаем 99-й перцентиль по количеству заказов
threshold_orders = users_stats['total_orders'].quantile(0.99)
print(f"Порог отсечения (99-й перцентиль): {threshold_orders} заказов")

# Создаем маску: оставляем только тех, кто ниже или равен порогу
mask_normal = users_stats['total_orders'] <= threshold_orders

# Фильтруем таблицу пользователей
users_normal = users_stats[mask_normal]
users_anomalies = users_stats[~mask_normal]

print(f"Всего уникальных пользователей: {users_stats.shape[0]}")
print(f"Пользователей-аномалий (выше порога): {users_anomalies.shape[0]}")
print(f"Доля аномалий среди пользователей: {(users_anomalies.shape[0]/users_stats.shape[0])*100:.2f}%")

# Важно: считаем, сколько заказов потеряли
lost_orders = users_anomalies['total_orders'].sum()
print(f"Потеряно заказов из-за фильтрации: {lost_orders} ({(lost_orders/total_orders_all)*100:.2f}%)")
# Out:
# Порог отсечения (99-й перцентиль): 152.0 заказов
# Всего уникальных пользователей: 21933
# Пользователей-аномалий (выше порога): 219
# Доля аномалий среди пользователей: 1.00%
# Потеряно заказов из-за фильтрации: 148999 (51.27%)

# %% [markdown]
# Один пользователь (или несколько) сделал нереальное количество заказов. * Статистика: Среднее = 13.2, Медиана = 2. Разница в 6 раз. Скорее всего, это либо бот/тестовый аккаунт, либо корпоративный клиент, который выкупает места пачками, либо ошибка дублирования данных.Значение в 10 258 заказов является статистическим выбросом, который искажает среднее арифметическое и дисперсию. Поскольку медиана составляет всего 2 заказа, поведение этого пользователя не отражает паттерны типичного клиента.
# Стратегия обработки:
# > 1. Исключить топ-0.1–1% пользователей с наибольшим числом заказов из анализа «типичного поведения».
# > 2. Или применить ограничение (capping) по 99-му перцентилю.

# %%
# 1. Получаем список ID нормальных пользователей (тех, кто <= 99-го перцентиля)
# users_normal - это тот датафрейм, который мы создали на шаге с фильтрацией
normal_user_ids = users_normal['user_id']

# 2. Фильтруем основной датасет: оставляем ТОЛЬКО заказы нормальных пользователей
final_df = clean_df_sorted[clean_df_sorted['user_id'].isin(normal_user_ids)].copy()

print(f"Исходное количество заказов: {clean_df_sorted.shape[0]}")
print(f"Количество заказов после фильтрации: {final_df.shape[0]}")
print(f"Удалено заказов: {clean_df_sorted.shape[0] - final_df.shape[0]} ({((clean_df_sorted.shape[0] - final_df.shape[0])/clean_df_sorted.shape[0])*100:.2f}%)")

# 3. Пересчитываем профиль пользователя на чистых данных
# Теперь переменная называется total_orders_clean
total_orders_clean = (
    final_df
    .groupby('user_id')
    .agg(
        # Даты
        first_order_dt=('order_dt', 'min'),
        last_order_dt=('order_dt', 'max'),
        
        # Характеристики первого заказа
        first_device=('device_type_canonical', 'first'),
        first_region_name=('region_name', 'first'),
        first_service_name=('service_name', 'first'),
        first_event_type=('event_type_main', 'first'),
        
        # Статистика по заказам
        total_orders=('order_id', 'nunique'),
        avg_revenue_rub=('revenue_rub', 'mean'),
        avg_tickets_count=('tickets_count', 'mean'),
        
        # Среднее время между покупками
        avg_days_between_orders=('days_since_prev', 'mean')
    )
    .reset_index()
)

# 4. Добавляем бинарные признаки лояльности
total_orders_clean = total_orders_clean.assign(
    is_two=lambda x: x['total_orders'] >= 2,
    is_five=lambda x: x['total_orders'] >= 5
)
# Проверка результата
print("\n--- Статистика по финальной выборке (total_orders_clean) ---")
print(f"Всего уникальных пользователей: {total_orders_clean.shape[0]}")
print(f"Доля пользователей с 2+ заказами: {total_orders_clean['is_two'].mean():.2%}")
print(f"Доля пользователей с 5+ заказами: {total_orders_clean['is_five'].mean():.2%}")
print(total_orders_clean[['is_two', 'is_five']].sum())
# Out:
# Исходное количество заказов: 290611
# Количество заказов после фильтрации: 141612
# Удалено заказов: 148999 (51.27%)
#
# --- Статистика по финальной выборке (total_orders_clean) ---
# Всего уникальных пользователей: 21714
# Доля пользователей с 2+ заказами: 61.44%
# Доля пользователей с 5+ заказами: 28.47%
# is_two     13340
# is_five     6181
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Я бы дополнил здесь описание, почему мы осуществляем фильтрацию по total_orders. Например, можно предположить, что эти аномалии относятся к перекупщикам билетов

# %% [markdown]
# Фильтрация аномалий (перекупщиков): * Выявлена группа из 219 пользователей (1%), совершивших 51.27% всех заказов. * Порог отсечения установлен на уровне 99-го перцентиля (152 заказа). * Цель: исключить искажение метрик лояльности и обеспечить обучение модели на поведении типичного пользователя.
# Дальнейшие расчёты (корреляции, модели) будут проводиться на очищенной колонке total_orders_clean, что обеспечит более надёжные и интерпретируемые результаты.»

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Фильтрация аномалий выполнена, данные готовы для анализа.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Елизавета, смысловое наполнение вывода хорошее. Пожалуйста, перепроверь итоговые результаты и вывод по разделу после доработки

# %% [markdown]
# ---
#
# ### Исследовательский анализ данных
#
# Следующий этап — исследование признаков, влияющих на возврат пользователей, то есть на совершение повторного заказа. Для этого используйте профили пользователей.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Все дальнейшие результаты по разделу ИАД также потребуют перепроверки после внесения правок выше

# %% [markdown]
# ####  Исследование признаков первого заказа и их связи с возвращением на платформу
#
# Исследуйте признаки, описывающие первый заказ пользователя, и выясните, влияют ли они на вероятность возвращения пользователя.
#
# ---
#
# ##### Задача Изучите распределение пользователей по признакам.
#
# - Сгруппируйте пользователей:
#     - по типу их первого мероприятия;
#     - по типу устройства, с которого совершена первая покупка;
#     - по региону проведения мероприятия из первого заказа;
#     - по билетному оператору, продавшему билеты на первый заказ.
# - Подсчитайте общее количество пользователей в каждом сегменте и их долю в разрезе каждого признака. Сегмент — это группа пользователей, объединённых определённым признаком, то есть объединённые принадлежностью к категории. Например, все клиенты, сделавшие первый заказ с мобильного телефона, — это сегмент.
# - Ответьте на вопрос: равномерно ли распределены пользователи по сегментам или есть выраженные «точки входа» — сегменты с наибольшим числом пользователей?
#
# ---

# %%
print(total_orders_clean.columns)
# Out:
# Index(['user_id', 'first_order_dt', 'last_order_dt', 'first_device',
#        'first_region_name', 'first_service_name', 'first_event_type',
#        'total_orders', 'avg_revenue_rub', 'avg_tickets_count',
#        'avg_days_between_orders', 'is_two', 'is_five'],
#       dtype='object')

# %%
# Используем колонку по первому мероприятию
col_name = 'first_event_type'

# 1. Группируем по типу первого мероприятия
df_genre = total_orders_clean.groupby(col_name).agg(count=('user_id', 'count'))

# 2. Считаем долю каждого сегмента
total_users = total_orders_clean.shape[0]
df_genre['share'] = df_genre['count'] / total_users

# 3. Сортируем: от самого популярного сегмента к самому редкому
df_genre_sorted = df_genre.sort_values(by='count', ascending=False)

# 4. Добавляем красивый формат процентов (например, "35.42%")
df_genre_sorted['share_percent'] = df_genre_sorted['share'].apply(lambda x: f"{x:.2%}")

# Вывод результата
print(f"Сегментация пользователей по типу ПЕРВОГО мероприятия (всего пользователей: {total_users}):")
print("-" * 50)
print(df_genre_sorted[['count', 'share_percent']])
# Out:
# Сегментация пользователей по типу ПЕРВОГО мероприятия (всего пользователей: 21714):
# --------------------------------------------------
#                   count share_percent
# first_event_type
# концерты           9616        44.28%
# другое             5425        24.98%
# театр              4262        19.63%
# стендап            1109         5.11%
# спорт               797         3.67%
# выставки            410         1.89%
# ёлки                 95         0.44%

# %%
# Используем колонку по типу устройства
col_name = 'first_device'

# 1. Группируем по типу первого устройства
df_genre = total_orders_clean.groupby(col_name).agg(count=('user_id', 'count'))

# 2. Считаем долю каждого сегмента
total_users = total_orders_clean.shape[0]
df_genre['share'] = df_genre['count'] / total_users

# 3. Сортируем: от самого популярного сегмента к самому редкому
df_genre_sorted = df_genre.sort_values(by='count', ascending=False)

# 4. Добавляем красивый формат процентов (например, "35.42%")
df_genre_sorted['share_percent'] = df_genre_sorted['share'].apply(lambda x: f"{x:.2%}")

# Вывод результата
print(f"Сегментация пользователей по типу первого устройства (всего пользователей: {total_users}):")
print("-" * 50)
print(df_genre_sorted[['count', 'share_percent']])
# Out:
# Сегментация пользователей по типу первого устройства (всего пользователей: 21714):
# --------------------------------------------------
#               count share_percent
# first_device
# mobile        17977        82.79%
# desktop        3737        17.21%

# %%
# Используем колонку по региону проведения мероприятия из первого заказа
col_name = 'first_region_name'

# 1. Группируем по региону проведения мероприятия из первого заказа
df_genre = total_orders_clean.groupby(col_name).agg(count=('user_id', 'count'))

# 2. Считаем долю каждого сегмента
total_users = total_orders_clean.shape[0]
df_genre['share'] = df_genre['count'] / total_users

# 3. Сортируем: от самого популярного сегмента к самому редкому
df_genre_sorted = df_genre.sort_values(by='count', ascending=False)

# 4. Добавляем красивый формат процентов (например, "35.42%")
df_genre_sorted['share_percent'] = df_genre_sorted['share'].apply(lambda x: f"{x:.2%}")

# Вывод результата
print(f"Сегментация пользователейпо региону проведения мероприятия из первого заказа (всего пользователей: {total_users}):")
print("-" * 50)
print(df_genre_sorted[['count', 'share_percent']])
# Out:
# Сегментация пользователейпо региону проведения мероприятия из первого заказа (всего пользователей: 21714):
# --------------------------------------------------
#                           count share_percent
# first_region_name
# Каменевский регион         7134        32.85%
# Североярская область       3762        17.33%
# Широковская область        1231         5.67%
# Озернинский край            676         3.11%
# Малиновоярский округ        532         2.45%
# ...                         ...           ...
# Залесский край                2         0.01%
# Тихогорская область           2         0.01%
# Верхозёрский край             1         0.00%
# Сосноводолинская область      1         0.00%
# Яснопольский округ            1         0.00%
#
# [81 rows x 2 columns]

# %%
# Используем колонку по билетному оператору, продавшему билеты на первый заказ
col_name = 'first_service_name'

# 1. Группируем по билетному оператору
df_genre = total_orders_clean.groupby(col_name).agg(count=('user_id', 'count'))

# 2. Считаем долю каждого сегмента
total_users = total_orders_clean.shape[0]
df_genre['share'] = df_genre['count'] / total_users

# 3. Сортируем: от самого популярного сегмента к самому редкому
df_genre_sorted = df_genre.sort_values(by='count', ascending=False)

# 4. Добавляем красивый формат процентов (например, "35.42%")
df_genre_sorted['share_percent'] = df_genre_sorted['share'].apply(lambda x: f"{x:.2%}")

# Вывод результата
print(f"Сегментация пользователей по билетному оператору (всего пользователей: {total_users}):")
print("-" * 50)
print(df_genre_sorted[['count', 'share_percent']])
# Out:
# Сегментация пользователей по билетному оператору (всего пользователей: 21714):
# --------------------------------------------------
#                         count share_percent
# first_service_name
# Билеты без проблем       5195        23.92%
# Мой билет                2998        13.81%
# Лови билет!              2814        12.96%
# Билеты в руки            2551        11.75%
# Облачко                  2178        10.03%
# Весь в билетах           1301         5.99%
# Лучшие билеты            1182         5.44%
# Прачечная                 587         2.70%
# Край билетов              457         2.10%
# Дом культуры              353         1.63%
# Яблоко                    318         1.46%
# Тебе билет!               308         1.42%
# Городской дом культуры    216         0.99%
# Мир касс                  205         0.94%
# За билетом!               203         0.93%
# Show_ticket               165         0.76%
# Быстробилет               163         0.75%
# ...

# %% [markdown]
# ВЫВОД
# из количества пользователей: 21714
# - Тип мероприятия: есть явные «точки входа»
# концерты           9616        44.28%
# другое             5425        24.98%
# театр              4262        19.63%
# Вывод: распределение неравномерное. Есть три крупных сегмента, на которые приходится почти 80 % всех пользователей. Это и есть главные «точки входа» на платформу. Остальные категории (выставки, спорт, стендап и т. д.) — это нишевые потоки.
# ...Что это значит: если ты будешь делать коммуникацию или улучшать UX, в первую очередь стоит фокусироваться на концертах, театре и сегменте «другое» — там сосредоточена основная масса пользователей.
# - Тип устройства: один доминирующий сегмент
# mobile        17977        82.79%
# desktop        3737        17.21%
# Вывод: распределение сильно перекошено в сторону мобильных устройств. Это тоже чёткая «точка входа»: большинство пользователей впервые покупают билеты со смартфонов.
# Что это значит: мобильная версия сайта или приложение — это главный канал привлечения и удержания. Если там есть проблемы (медленная загрузка, неудобная оплата), это сразу ударит по большому числу пользователей.
# - Регион: выраженная концентрация
# Каменевский регион         7134        32.85%
# Североярская область       3762        17.33%
# Широковская область        1231         5.67%
# остальные регионы — меньше.
# Вывод: распределение неравномерное, есть явный лидер (Каменевский регион) и ещё один крупный регион. Это значит, что географически аудитория сконцентрирована: почти каждый шестой пользователь — из одного региона.
# Что это значит: поведение пользователей региона может сильно влиять на общие метрики платформы. Имеет смысл отдельно анализировать этот регион: возможно, там лучше работает реклама, или там больше крупных мероприятий, или выше лояльность.
# - Билетный оператор: рынок сильно концентрирован
# Билеты без проблем       5195        23.92%
# Мой билет                2998        13.81%
# Лови билет!              2814        12.96%
# Билеты в руки            2551        11.75%
# Облачко                  2178        10.03%
# Весь в билетах           1301         5.99%
# Вывод: распределение очень неравномерное. Несколько крупных операторов занимают огромную долю рынка, а остальные — это мелкие игроки с долей меньше 1 % (а у некоторых — меньше 0,02 %).
# Что это значит: «точки входа» здесь — это именно крупные операторы.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Елизавета, обрати внимание, согласно ТЗ здесь нам необходимо подсчитать общее количество пользователей в каждом сегменте и их долю в разрезе каждого признака. Покажу пример, как здесь это можно сделать по типам мероприятий:
#
#     #сгруппируем по типу первого мероприятия, посчитаем кол-во и долю в каждом сегменте
#     df_genre = df_1.groupby('first_order_genre').agg(count=('user_id', 'count'))
#     df_genre['mean'] = df_genre['count'] / df_1.shape[0]
#
#     #выведем результат
#     df_genre.sort_values('count',ascending=False)
#
# В этом ключе и предлагаю перепроверить все результаты и выводы в этом пункте

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Теперь все результаты корректны

# %% [markdown]
# ---
#
# ##### Задача Проанализируйте возвраты пользователей:
#
# - Для каждого сегмента вычислите долю пользователей, совершивших два и более заказа.
# - Визуализируйте результат подходящим графиком. Если сегментов слишком много, то поместите на график только 10 сегментов с наибольшим количеством пользователей. Такое возможно с сегментами по региону и по билетному оператору.
# - Ответьте на вопросы:
#     - Какие сегменты пользователей чаще возвращаются на Яндекс Афишу?
#     - Наблюдаются ли успешные «точки входа» — такие сегменты, в которых пользователи чаще совершают повторный заказ, чем в среднем по выборке?
#
# При интерпретации результатов учитывайте размер сегментов: если в сегменте мало пользователей (например, десятки), то доли могут быть нестабильными и недостоверными, то есть показывать широкую вариацию значений.
#
# ---

# %%
# 1. Считаем долю возврата (is_two) внутри каждого типа ПЕРВОГО мероприятия
# .mean() сработает идеально: посчитает долю единиц (True) в каждой группе
return_rate_by_first_event = total_orders_clean.groupby('first_event_type')['is_two'].mean()

# 2. Считаем размер каждого сегмента (сколько пользователей в нём)
segment_size = total_orders_clean.groupby('first_event_type')['user_id'].count()

# 3. Собираем всё в одну таблицу для удобства
stats_by_first_event = pd.DataFrame({
    'return_rate': return_rate_by_first_event,
    'total_users': segment_size
})

# 4. Сортируем по размеру сегмента (чтобы сверху были самые крупные)
stats_by_first_event = stats_by_first_event.sort_values(by='total_users', ascending=False)

# Добавляем красивый формат процентов
stats_by_first_event['return_rate_percent'] = stats_by_first_event['return_rate'].apply(lambda x: f"{x:.1%}")

print("Доля возврата пользователей в разрезе типа ПЕРВОГО мероприятия:")
stats_by_first_event[['total_users', 'return_rate_percent']].head(10)
# Out:
# Доля возврата пользователей в разрезе типа ПЕРВОГО мероприятия:
#                   total_users return_rate_percent
# first_event_type
# концерты                 9616               62.1%
# другое                   5425               59.6%
# театр                    4262               63.5%
# стендап                  1109               60.7%
# спорт                     797               55.8%
# выставки                  410               63.7%
# ёлки                       95               54.7%

# %%
# Строим график для Топ-10 сегментов ---
top_10_segments = stats_by_first_event.head(10)

plt.figure(figsize=(12, 7))
ax = sns.barplot(
    data=top_10_segments.reset_index(), 
    x='return_rate', 
    y='first_event_type', 
    palette='viridis', 
    edgecolor='black'  # Чёрные контуры делают график чище
)

# Добавляем подписи значений (проценты) прямо на столбцы
for i, v in enumerate(top_10_segments['return_rate']):
    # v - это доля (например, 0.35), умножаем на 100 для процентов
    ax.text(v + 0.01, i, f"{v*100:.1f}%", va='center', fontsize=11, fontweight='bold')

# Рисуем вертикальную линию: средний возврат по ВСЕЙ платформе
overall_avg = total_orders_clean['is_two'].mean()
plt.axvline(overall_avg, color='red', linestyle='--', linewidth=2, label=f'Среднее по платформе: {overall_avg*100:.1f}%')

# Оформление
plt.title('Доля вернувшихся пользователей (is_two) по типу ПЕРВОГО мероприятия\n(Топ-10 по размеру сегмента)', fontsize=14, pad=20)
plt.xlabel('Доля вернувшихся пользователей', fontsize=12)
plt.ylabel('Тип мероприятия', fontsize=12)
plt.xlim(0, max(top_10_segments['return_rate']) + 0.1) # Чуть увеличим ось X, чтобы текст не обрезался
plt.grid(axis='x', linestyle='--', alpha=0.3)
plt.legend(loc='lower right')

plt.tight_layout()
plt.show()

#  Вывод таблицы рядом с графиком (для отчёта) ---
print("Статистика для Топ-10 сегментов:")
# Форматируем вывод красиво
display_df = top_10_segments.copy()
display_df['return_rate_percent'] = (display_df['return_rate'] * 100).round(1).astype(str) + '%'
print(display_df[['total_users', 'return_rate_percent']])
# Out:
# Статистика для Топ-10 сегментов:
#                   total_users return_rate_percent
# first_event_type
# концерты                 9616               62.1%
# другое                   5425               59.6%
# театр                    4262               63.5%
# стендап                  1109               60.7%
# спорт                     797               55.8%
# выставки                  410               63.7%
# ёлки                       95               54.7%

# %% [markdown]
# Более надёжными с точки зрения бизнеса выглядят крупные сегменты: в сегменте выставки (63,7%), театр (63,5%), концерты (62.1%) высокий уровень повторных заказов сохраняется даже при базе пользователей (более 400–9000 человек). Это говорит о стабильной лояльности аудитории в этих категориях.
# В среднем чуть больше половины всех пользователей делают второй заказ.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Сводные таблицы и гистограммы здесь необходимо представить также для каждого из сегментов, а не только по типам мероприятий. Предлагаю рассмотреть подобный пример расчета для типов мероприятий:
#
#     #рассчитаем долю возвращающихся пользователей в разрезе категории мероприятия первого заказа
#     df_genre['share_return'] = df_1.groupby('first_order_genre')['is_two'].mean()
#     df_genre.sort_values('count',ascending=False)
#
# Или для регионов:
#
#     #рассчитаем долю возвращающихся пользователей в разрезе региона первого заказа для топ 10 регионов
#     df_region['share_return'] = df_1.groupby('first_order_region')['is_two'].mean()
#     region_top_sort = df_region.sort_values('count',ascending=False).head(10)
#     region_top_sort
#
# По остальным сегментам предлагаю доработать самостоятельно) Также повторюсь про необходимость перепроверить все выводы

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v2<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Елизавета, доли возвратов по мероприятиям ты рассмотрела, молодец. Но, согласно ТЗ, здесь необходимо исследовать возвраты и по другим ключевым признакам (типу устройства, региону проведения мероприятия, билетному оператору). Предлагаю доработать эти важные аспекты, а чтобы тебе было проще, на проглой итерации я оставлял примеры, как это можно сделать

# %% [markdown]
# ---
#
# ##### Задача  Продуктовые гипотезы:
#
# - **Гипотеза 1.** Тип мероприятия влияет на вероятность возврата на Яндекс Афишу: пользователи, которые совершили первый заказ на спортивные мероприятия, совершают повторный заказ чаще, чем пользователи, оформившие свой первый заказ на концерты.
# - **Гипотеза 2.** В регионах, где больше всего пользователей посещают мероприятия, выше доля повторных заказов, чем в менее активных регионах.
#
# ---

# %%
# 1. Находим дату первого заказа для каждого пользователя
# Нам нужен минимальный order_ts для каждого user_id
first_orders = df.groupby('user_id')['order_ts'].min().reset_index()
first_orders.columns = ['user_id', 'first_order_ts']

# 2. Присоединяем эту дату обратно к исходному датасету, чтобы найти тип первого мероприятия
df_with_first = pd.merge(df, first_orders, on='user_id', how='left')

# 3. Фильтруем: оставляем только те строки, где дата заказа равна дате первого заказа
# Так мы получим ровно одну строку на пользователя - его самое первое действие
users_first_event = df_with_first[df_with_first['order_ts'] == df_with_first['first_order_ts']].copy()

# 4. Оставляем только нужные колонки: user_id, тип первого мероприятия
# И сразу переименуем колонку типа мероприятия в first_event_type, чтобы не путаться
users_first_event = users_first_event[['user_id', 'event_type_main']].rename(columns={'event_type_main': 'first_event_type'})

# 5. Добавляем признак возврата (returned)
# Считаем общее количество заказов на пользователя
orders_count = df.groupby('user_id')['order_id'].nunique().reset_index()
orders_count.columns = ['user_id', 'total_orders']
orders_count['returned'] = (orders_count['total_orders'] >= 2).astype(int)

# 6. Склеиваем: теперь у каждого пользователя есть "первый тип" и "вернулся ли он"
users_analysis = pd.merge(users_first_event, orders_count[['user_id', 'returned']], on='user_id', how='left')

# Проверка: нет ли пропусков
print("Пропуски в returned:", users_analysis['returned'].isnull().sum())
print("Первые 5 строк таблицы для анализа:")
print(users_analysis.head())
# Out:
# Пропуски в returned: 0
# Первые 5 строк таблицы для анализа:
#            user_id first_event_type  returned
# 0  0002849b70a3ce2            театр         0
# 1  0005ca5e93f2cf4         выставки         1
# 2  000898990054619           другое         1
# 3  00096d1f542ab2b            театр         0
# 4  000a55a418c128c            театр         1

# %%
# 1. Общее число уникальных пользователей по типу ПЕРВОГО мероприятия
# (В users_analysis каждый пользователь уже встречается 1 раз, поэтому count() достаточно)
users_by_first_event = users_analysis.groupby('first_event_type')['user_id'].count()

# 2. Число вернувшихся пользователей (где returned == 1) по типу ПЕРВОГО мероприятия
returned_users_by_first_event = users_analysis[users_analysis['returned'] == 1].groupby('first_event_type')['user_id'].count()

# 3. Считаем долю
share_returned_first_event = returned_users_by_first_event / users_by_first_event

# Сортируем по убыванию и выводим
print(share_returned_first_event.sort_values(ascending=False))
# Out:
# first_event_type
# выставки    0.640097
# театр       0.638915
# концерты    0.623956
# стендап     0.610018
# другое      0.601202
# спорт       0.562189
# ёлки        0.547368
# Name: user_id, dtype: float64

# %%
# Пересчитываем количество заказов на пользователя и флаг возврата
# Считаем, сколько заказов сделал каждый user_id
orders_per_user = clean_df.groupby('user_id')['order_id'].count().reset_index() 
orders_per_user.columns = ['user_id', 'order_count']

# Присоединяем обратно к основному датасету 
clean_df = clean_df.merge(orders_per_user, on='user_id', how='left')

# Проверяем типы данных
print(f"Тип user_id в clean_df: {clean_df['user_id'].dtype}")
print(f"Тип user_id в orders_per_user: {orders_per_user['user_id'].dtype}")

# Проверяем, добавилась ли колонка и есть ли там данные
clean_df[['user_id', 'order_count']].head(10)
# Создаем флаг возврата: 1 если заказов >= 2, иначе 0 
clean_df['returned'] = (clean_df['order_count'] >= 2).astype(int)
# Out:
# Тип user_id в clean_df: object
# Тип user_id в orders_per_user: object

# %%
# Считаем долю возврата по типам мероприятий (для Гипотезы 1) ---
# Общее число уникальных пользователей в каждом типе мероприятия 
users_by_event = clean_df.groupby('event_type_main')['user_id'].nunique()

# Число уникальных пользователей, которые вернулись (returned == 1),
returned_users_by_event = clean_df[clean_df['returned'] == 1].groupby('event_type_main')['user_id'].nunique()

# Вычисляем долю: (вернувшиеся пользователи) / (все пользователи в сегменте) 
share_returned_event = returned_users_by_event.reindex(users_by_event.index, fill_value=0) / users_by_event

print("\n--- Доля возврата по типам мероприятий ---")
print(share_returned_event.sort_values(ascending=False))
# Out:
# --- Доля возврата по типам мероприятий ---
# event_type_main
# ёлки        0.940195
# выставки    0.906933
# стендап     0.865887
# спорт       0.861526
# театр       0.812229
# другое      0.764649
# концерты    0.728005
# Name: user_id, dtype: float64

# %%
# Проверка Гипотезы 1 (Спорт vs Концерты) ---
sport_rate = share_returned_event.get('спорт', 0) 
concert_rate = share_returned_event.get('концерты', 0) 
overall_rate = clean_df['returned'].mean()
print(f"\n--- Проверка Гипотезы 1 ---")
print(f"Доля возврата (спорт): {sport_rate:.2%}")
print(f"Доля возврата (концерты): {concert_rate:.2%}")
print(f"Средний возврат по платформе: {overall_rate:.2%}")
if sport_rate > concert_rate: 
    print("Вывод: Гипотеза ПОДТВЕРЖДАЕТСЯ. Пользователи со спортивных мероприятий возвращаются чаще.")
else: 
    print("Вывод: Гипотеза НЕ ПОДТВЕРЖДАЕТСЯ. Пользователи с концертов возвращаются чаще или доля одинаковая.")
# Out:
# --- Проверка Гипотезы 1 ---
# Доля возврата (спорт): 86.15%
# Доля возврата (концерты): 72.80%
# Средний возврат по платформе: 97.12%
# Вывод: Гипотеза ПОДТВЕРЖДАЕТСЯ. Пользователи со спортивных мероприятий возвращаются чаще.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v2<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> В прошлом пункте мы установили, что доля возвратов по спортивным мероприятиям составляет 0.56, тогда как по концертам - 0.62. Следовательно, здесь гипотеза у нас не подтверждается

# %%
# Проверка Гипотезы 2 (Топ-регионы vs Остальные) ---

# 1. Находим топ-10 регионов по числу пользователей (по количеству уникальных юзеров)
top_regions = clean_df.groupby('region_name')['user_id'].nunique().sort_values(ascending=False).head(10).index

# 2. Разделяем датасет на две группы: "Топ-10 активных" и "Все остальные"
df_top = clean_df[clean_df['region_name'].isin(top_regions)]
df_other = clean_df[~clean_df['region_name'].isin(top_regions)]

# 3. Считаем долю возврата для группы "Топ-10"
# Важно: считаем уникальных пользователей, а не строки заказов
users_top_count = df_top['user_id'].nunique()
returned_top_count = df_top[df_top['returned'] == 1]['user_id'].nunique()
share_top_regions = returned_top_count / users_top_count if users_top_count > 0 else 0

# 4. Считаем долю возврата для группы "Остальные регионы"
users_other_count = df_other['user_id'].nunique()
returned_other_count = df_other[df_other['returned'] == 1]['user_id'].nunique()
share_other_regions = returned_other_count / users_other_count if users_other_count > 0 else 0

# 5. Выводим результаты
print(f"\n--- Проверка Гипотезы 2 ---")
print(f"Количество пользователей в топ-10 регионах: {users_top_count}")
print(f"Доля возврата в топ-10 регионах: {share_top_regions:.2%}")
print(f"Количество пользователей в остальных регионах: {users_other_count}")
print(f"Доля возврата в остальных регионах: {share_other_regions:.2%}")
print(f"Средний возврат по всей платформе: {overall_rate:.2%}")

# 6. Формулируем вывод по гипотезе
if share_top_regions > share_other_regions:
    print("Вывод: Гипотеза ПОДТВЕРЖДАЕТСЯ. В самых активных регионах доля повторных заказов выше.")
else:
    print("Вывод: Гипотеза НЕ ПОДТВЕРЖДАЕТСЯ. В менее активных регионах доля возврата такая же или даже выше.")
# Out:
# --- Проверка Гипотезы 2 ---
# Количество пользователей в топ-10 регионах: 17561
# Доля возврата в топ-10 регионах: 66.97%
# Количество пользователей в остальных регионах: 10148
# Доля возврата в остальных регионах: 74.64%
# Средний возврат по всей платформе: 97.12%
# Вывод: Гипотеза НЕ ПОДТВЕРЖДАЕТСЯ. В менее активных регионах доля возврата такая же или даже выше.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Елизавета, предлагаю еще раз перепроверить заключения по обеим гипотезам после доработки, т.к. они могут несколько измениться

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v2<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Расчеты и выводы по второй гипотезе также необходимо будет перепроверить после доработки предыдущего пункта

# %% [markdown]
# ---
#
# ####  Исследование поведения пользователей через показатели выручки и состава заказа
#
# Изучите количественные характеристики заказов пользователей, чтобы узнать среднюю выручку сервиса с заказа и количество билетов, которое пользователи обычно покупают.
#
# Эти метрики важны не только для оценки выручки, но и для оценки вовлечённости пользователей. Возможно, пользователи с более крупными и дорогими заказами более заинтересованы в сервисе и поэтому чаще возвращаются.
#
# ---
# ##### Задача  Проследите связь между средней выручкой сервиса с заказа и повторными заказами.
#
# - Постройте сравнительные гистограммы распределения средней выручки с билета (`avg_revenue_rub`):
#     - для пользователей, совершивших один заказ;
#     - для вернувшихся пользователей, совершивших 2 и более заказа.
# - Ответьте на вопросы:
#     - В каких диапазонах средней выручки концентрируются пользователи из каждой группы?
#     - Есть ли различия между группами?
#
# Текст на сером фоне:
#
# **Рекомендация:**
#
# 1. Используйте одинаковые интервалы (`bins`) и прозрачность (`alpha`), чтобы визуально сопоставить распределения.
# 2. Задайте параметру `density` значение `True`, чтобы сравнивать форму распределений, даже если число пользователей в группах отличается.
#
# ---

# %%
#средняя цена одного билета
clean_df['avg_revenue_rub'] = clean_df['revenue_rub'] / clean_df['tickets_count']

# %%
# Группа А: Те, кто сделал только 1 заказ (не вернулись). Берем колонку avg_revenue_rub только для них.
one_ord = total_orders_clean[total_orders_clean['is_two'] == 0]['avg_revenue_rub']

# Группа Б: Те, кто сделал 2+ заказа (вернулись).
sev_ord = total_orders_clean[total_orders_clean['is_two'] == 1]['avg_revenue_rub']

# Проверка: сколько человек в каждой группе
print(f"Разовые пользователи (1 заказ): {len(one_ord)} чел.")
print(f"Лояльные пользователи (2+ заказа): {len(sev_ord)} чел.")

# ВСПОМОГАТЕЛЬНАЯ ФУНКЦИЯ (поиск пика) 
def get_histogram_peak(data, bins=40):
    """
    Находит примерное значение пика гистограммы.
    data: Series с числами (например, one_ord или sev_ord)
    bins: количество столбцов на графике
    """
    # Если данных нет, возвращаем 0, чтобы не было ошибки
    if len(data) == 0:
        return 0
    
    # np.histogram строит гистограмму и возвращает высоты столбцов (counts) и границы интервалов (bin_edges)
    counts, bin_edges = np.histogram(data, bins=bins, density=True)
    
    # Находим индекс самого высокого столбца
    max_idx = np.argmax(counts)
    
    # Возвращаем середину этого интервала (это и есть примерное значение пика)
    return (bin_edges[max_idx] + bin_edges[max_idx+1]) / 2

#ПОСТРОЕНИЕ ГРАФИКА
plt.figure(figsize=(14, 8))
# Рисуем гистограмму для разовых пользователей (теплый цвет)
plt.hist(one_ord, bins=40, color='salmon', edgecolor='black', density=True, alpha=0.6, label='1 заказ (не вернулись)')
# Рисуем гистограмму для лояльных пользователей (холодный цвет) 
plt.hist(sev_ord, bins=40, color='skyblue', edgecolor='black', density=True, alpha=0.6, label='2+ заказа (вернулись)')
# Добавляем сетку 
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
# Заголовок и подписи 
plt.title('Распределение средней выручки заказа (avg_revenue_rub)\nСравнение: разовые vs лояльные пользователи', 
          fontsize=16, pad=20) 
plt.xlabel('Средняя выручка заказа, руб.', 
 fontsize=12) 
plt.ylabel('Плотность распределения', 
           fontsize=12) 
plt.legend(fontsize=12)

# АВТОМАТИЧЕСКИЙ ПОИСК И ПОДПИСЬ ПИКОВ 
peak_one = get_histogram_peak(one_ord, bins=40) 
peak_sev = get_histogram_peak(sev_ord, bins=40)
# Подписываем пики на графике 
plt.text(peak_one, 0.00015, 
         f'Пик: ~{peak_one:.0f} ₽', 
         color='darkred', 
         fontsize=12, 
         fontweight='bold', 
         bbox=dict(facecolor='white', 
                   alpha=0.8, 
                   edgecolor='none'))
plt.text(peak_sev, 0.00012, 
         f'Пик: ~{peak_sev:.0f} ₽', 
         color='darkblue', 
         fontsize=12, 
         fontweight='bold', 
         bbox=dict(facecolor='white',
                   alpha=0.8,
                   edgecolor='none'))
plt.tight_layout()
plt.show()

# ВЫВОД СТАТИСТИКИ ДЛЯ ОТЧЁТА 
mean_one = one_ord.mean()
mean_sev = sev_ord.mean()
median_one = one_ord.median()
median_sev = sev_ord.median()
std_one = one_ord.std()
std_sev = sev_ord.std()
count_one = len(one_ord)
count_sev = len(sev_ord)

# ВЫВОД ТАБЛИЦЫ 
print("\n" + "="*70)
print(f"{'Метрика':<35} | {'Разовые (1 заказ)':<20} | {'Лояльные (2+)':<20}")
print("="*70)
print(f"{'Среднее значение (Mean), руб.':<35} | {mean_one:>18.2f} | {mean_sev:>18.2f}")
print(f"{'Медиана (Median), руб.':<35} | {median_one:>18.2f} | {median_sev:>18.2f}")
print(f"{'Стандартное отклонение (Std), руб.':<35} | {std_one:>18.2f} | {std_sev:>18.2f}")
print(f"{'Количество пользователей':<35} | {count_one:>18} | {count_sev:>18}")
print("="*70)
# Out:
# Разовые пользователи (1 заказ): 8374 чел.
# Лояльные пользователи (2+ заказа): 13340 чел.
# ...
# Метрика                             | Разовые (1 заказ)    | Лояльные (2+)
# ...
# Среднее значение (Mean), руб.       |             660.92 |             683.07
# Медиана (Median), руб.              |             394.39 |             518.70
# Стандартное отклонение (Std), руб.  |            1040.74 |             947.13
# Количество пользователей            |               8374 |              13340
# ...

# %% [markdown]
# -Для наглядной проверки гипотезы о различии в чеках были построены наложенные гистограммы распределения средней выручки заказа (avg_revenue_rub) для двух сегментов: пользователей с 1 заказом и пользователей с 2+ заказами.
# Анализ распределения:
# * Сегмент "Разовые пользователи" (1 заказ): Распределение имеет выраженный перекос влево. На графике чётко виден пик в диапазоне 100–200 ₽, после которого следует резкий спад частоты. Это подтверждает наличие большого количества дешёвых билетов в первом заказе (например, промо-билеты, места в дальних рядах). Медиана этого сегмента составляет 394.39 ₽, что согласуется с визуальным положением пика.
# * Сегмент "Лояльные пользователи" (2+ заказа): Распределение сдвинуто вправо относительно разовых пользователей. Пик гистограммы смещается к диапазону 500–600 ₽. Кривая становится более плавной, без резких обрывов, что говорит о более разнообразном, но в среднем более дорогом выборе мероприятий. Медиана здесь составляет 518.70 ₽.
# Интерпретация: Смещение пика распределения выручки у лояльных пользователей вправо (с ~200 ₽ до ~550 ₽) свидетельствует о том, что повторные покупки ассоциируются с более дорогими билетами. Вероятно, пользователи, которым понравился формат площадки, в следующий раз выбирают лучшие места или идут на более статусные мероприятия.
# Таким образом, визуализация подтверждает статистические расчёты: лояльная аудитория не просто чаще покупает, но и формирует более высокий средний чек.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Елизавета, для большей детализации я рекомендовал бы использовать и большее значение "корзин" на графиках здесь и далее, чтобы не упустить возможные дополнительные особенности наших выборок, как этого от нас и требует ТЗ. Например, так:
#
#     #разделим пользователей на две группы
#     one_ord = df_1[df_1['is_two'] == 0]['avg_revenue_rub']
#     sev_ord = df_1[df_1['is_two'] > 0]['avg_revenue_rub']
#     #построим гистрограмму распределения средней выручки
#     plt.figure(figsize=(14,10))
#     plt.hist(one_ord,bins=30,color='green',edgecolor='black',density=True,alpha=0.7,label='Пользователи совершившие 1 заказ')
#     plt.hist(sev_ord,bins=30,color='skyblue',edgecolor='black',density=True,alpha=0.7,label='Пользователи совершившие 2 и более заказов')
#     plt.grid(True)
#     plt.title('Распределение средней выручки заказа')
#     plt.xlabel('среднее в руб.')
#     plt.ylabel('Плотность')
#     plt.legend()
#     plt.show()
#
# Предлагаю поработать над наглядностью и конкретизацией выводов (например, отметить, что для пользователей с одним заказом распределение резко смещено влево. Пик около 100–200 руб, затем резкий спад. Для возвращающихся пользователей распределение сдвинуто правее, пик ближе к 500–600 руб, и само распределение без скачков, более плавное)

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Я бы предложил лишь поработать над наглядностью и уменьшить масштаб

# %% [markdown]
# ---
#
# ##### Задача Сравните распределение по средней выручке с заказа в двух группах пользователей:
#
# - совершившие 2–4 заказа;
# - совершившие 5 и более заказов.
#
# Ответьте на вопрос: есть ли различия по значению средней выручки с заказа между пользователями этих двух групп?
#
# ---

# %%
# Группируем по пользователю и считаем нужные метрики
user_stats = clean_df.groupby('user_id').agg(
    order_count=('order_id', 'nunique'),   
    avg_order_revenue=('revenue_rub', 'mean')     
).reset_index()

print(user_stats.head())
# Out:
#            user_id  order_count  avg_order_revenue
# 0  0002849b70a3ce2            1        1521.940000
# 1  0005ca5e93f2cf4            2         774.010000
# 2  000898990054619            3         767.213333
# 3  00096d1f542ab2b            1         917.830000
# 4  000a55a418c128c            2          61.310000

# %%
# Группа 1: пользователи с 2–4 заказами
group_2_4 = user_stats[(user_stats['order_count'] >= 2) & (user_stats['order_count'] <= 4)]

# Группа 2: пользователи с 5 и более заказами
group_5_plus = user_stats[user_stats['order_count'] >= 5]

print(f"В группе 2-4 заказа: {len(group_2_4)} пользователей")
print(f"В группе 5+ заказов: {len(group_5_plus)} пользователей")
# Out:
# В группе 2-4 заказа: 7159 пользователей
# В группе 5+ заказов: 6400 пользователей

# %%
plt.figure(figsize=(12, 7))

# Гистограмма для группы 2-4 заказа (например, синий цвет)
plt.hist(group_2_4['avg_order_revenue'], 
         bins=50, 
         alpha=0.5, 
         density=True, 
         color='blue', 
         label='2–4 заказа')

# Гистограмма для группы 5+ заказов (например, оранжевый цвет)
plt.hist(group_5_plus['avg_order_revenue'], 
         bins=50, 
         alpha=0.5, 
         density=True, 
         color='orange', 
         label='5+ заказов')

plt.title('Сравнение средней выручки с заказа между лояльными пользователями', fontsize=16)
plt.xlabel('Средняя выручка с заказа, руб.', fontsize=12)
plt.ylabel('Плотность распределения', fontsize=12)
plt.legend(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xscale('log')  
plt.show()

# %%
#Количественная проверка (средние значения)
mean_2_4 = group_2_4['avg_order_revenue'].mean()
mean_5_plus = group_5_plus['avg_order_revenue'].mean()
median_2_4 = group_2_4['avg_order_revenue'].median()
median_5_plus = group_5_plus['avg_order_revenue'].median()

print(f"Группа 2–4 заказа: среднее = {mean_2_4:,.2f} руб., медиана = {median_2_4:,.2f} руб.")
print(f"Группа 5+ заказов: среднее = {mean_5_plus:,.2f} руб., медиана = {median_5_plus:,.2f} руб.")

# Посчитаем разницу в процентах, чтобы было нагляднее
if mean_2_4 > 0:
    diff_percent = ((mean_5_plus - mean_2_4) / mean_2_4) * 100
    print(f"Разница средних: {diff_percent:+.2f}% (группа 5+ выше/ниже)")
else:
    print("Невозможно рассчитать процентную разницу (среднее значение в группе 2-4 равно 0)")
# Out:
# Группа 2–4 заказа: среднее = 690.18 руб., медиана = 485.02 руб.
# Группа 5+ заказов: среднее = 672.49 руб., медиана = 546.74 руб.
# Разница средних: -2.56% (группа 5+ выше/ниже)

# %%
# Дополнительный уровень анализа (для крутых инсайтов)
#Если хочешь сделать анализ ещё глубже, посмотри на дисперсию (разброс значений).

std_2_4 = group_2_4['avg_order_revenue'].std()
std_5_plus = group_5_plus['avg_order_revenue'].std()

print(f"Стандартное отклонение (2-4 заказа): {std_2_4:,.2f}")
print(f"Стандартное отклонение (5+ заказов): {std_5_plus:,.2f}") 
#Если у группы «5+» стандартное отклонение больше, значит, их поведение более разнородное: там есть и те, кто покупает дешёвые билеты, и те, кто берёт VIP.
#Если отклонение меньше, значит, эта группа более предсказуема и однородна по своим тратам.
# Out:
# Стандартное отклонение (2-4 заказа): 1,044.64
# Стандартное отклонение (5+ заказов): 806.48

# %% [markdown]
# ВЫВОД
#
# Да, различия есть, но они неочевидны при взгляде только на среднее значение.
# Среднее значение у группы "2–4 заказа" (690.18 ₽) незначительно выше, чем у группы "5+ заказов" (672.49 ₽).
# Однако медиана у группы "5+ заказов" существенно выше (546.74 ₽ против 485.02 ₽), что говорит о более высоком "типичном" чеке у самых лояльных пользователей.
# Разброс данных (Std) у группы "2–4 заказа" значительно выше (1044 ₽ против 806 ₽), что указывает на наличие сильных выбросов (редких очень дорогих заказов), искажающих среднее значение.
# Вывод: Группа пользователей с 5+ заказами демонстрирует более стабильное и в целом более дорогое покупательское поведение. Снижение среднего чека объясняется отсутствием экстремальных выбросов, а не снижением платёжеспособности

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Здесь также предлагаю еще раз все перепроверить

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v2<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Елизавета, сейчас очень сложно что либо интерпретировать по графику выше. Могу показать здесь и такой вариант:
#
#     #разделим пользователей на две группы
#     two_four_orders = df_1[(df_1['total_orders'] >= 2) & (df_1['total_orders'] <= 4)]['avg_revenue_rub']
#     five_over_orders = df_1[df_1['total_orders'] >= 5]['avg_revenue_rub']
#     #построим гистрограмму распределения средней выручки
#     plt.figure(figsize=(14,10))
#     plt.hist(two_four_orders,bins=30,color='green',edgecolor='black',density=True,alpha=0.7,label='Пользователи совершившие 2-4 заказ')
#     plt.hist(five_over_orders,bins=30,color='skyblue',edgecolor='black',density=True,alpha=0.7,label='Пользователи совершившие 5 и более заказов')
#     plt.grid(True)
#     plt.title('Распределение средней выручки заказа')
#     plt.xlabel('среднее в руб.')
#     plt.ylabel('Плотность')
#     plt.legend()
#     plt.show()
#
# Так графики получатся более наглядными и понятными

# %% [markdown]
# ---
#
# ##### Задача Проанализируйте влияние среднего количества билетов в заказе на вероятность повторной покупки.
#
# - Изучите распределение пользователей по среднему количеству билетов в заказе (`avg_tickets_count`) и опишите основные наблюдения.
# - Разделите пользователей на несколько сегментов по среднему количеству билетов в заказе:
#     - от 1 до 2 билетов;
#     - от 2 до 3 билетов;
#     - от 3 до 5 билетов;
#     - от 5 и более билетов.
# - Для каждого сегмента подсчитайте общее число пользователей и долю пользователей, совершивших повторные заказы.
# - Ответьте на вопросы:
#     - Как распределены пользователи по сегментам — равномерно или сконцентрировано?
#     - Есть ли сегменты с аномально высокой или низкой долей повторных покупок?
#
# ---

# %%
# Считаем среднее количество билетов на пользователя
#Нам нужно для каждого user_id посчитать среднее значение tickets_count по всем его заказам.

# Агрегируем данные по пользователям
user_stats = clean_df.groupby('user_id').agg(
    order_count=('order_id', 'nunique'),
    avg_tickets_count=('tickets_count', 'mean'),
    avg_revenue=('revenue_rub', 'mean')
).reset_index()

# Добавляем флаг возврата (уже знакомый нам)
# 1, если заказов >= 2, иначе 0
user_stats['returned'] = (user_stats['order_count'] >= 2).astype(int)

print(user_stats.head())
# Out:
#            user_id  order_count  avg_tickets_count  avg_revenue  returned
# 0  0002849b70a3ce2            1           4.000000  1521.940000         0
# 1  0005ca5e93f2cf4            2           3.000000   774.010000         1
# 2  000898990054619            3           2.666667   767.213333         1
# 3  00096d1f542ab2b            1           4.000000   917.830000         0
# 4  000a55a418c128c            2           1.500000    61.310000         1

# %%
# Разбиваем пользователей на сегменты
#Теперь создадим колонку ticket_segment, которая будет определять, к какой группе относится пользователь
# Задаём границы сегментов
bins = [0, 2, 3, 5, float('inf')]
labels = ['1-2 билета', '2-3 билета', '3-5 билетов', '5+ билетов']

# Создаём сегмент
user_stats['ticket_segment'] = pd.cut(user_stats['avg_tickets_count'], bins=bins, labels=labels, right=True)


print(user_stats['ticket_segment'].value_counts().sort_index())
# Out:
# 1-2 билета      6120
# 2-3 билета     10091
# 3-5 билетов     5513
# 5+ билетов       209
# Name: ticket_segment, dtype: int64

# %%
# Считаем долю вернувшихся в каждом сегменте
#Теперь для каждого сегмента нужно посчитать:
#1. Общее число пользователей.
#2. Число вернувшихся (у кого returned == 1).
#3. Долю вернувшихся.

# Группируем по сегменту
segment_analysis = user_stats.groupby('ticket_segment').agg(
    total_users=('user_id', 'nunique'),
    returned_users=('returned', 'sum')
).reset_index()

# Считаем долю
segment_analysis['return_rate'] = segment_analysis['returned_users'] / segment_analysis['total_users']

# Сортируем по названию сегмента для красоты
segment_analysis = segment_analysis.sort_values('ticket_segment')

print(segment_analysis)
# Out:
#   ticket_segment  total_users  returned_users  return_rate
# 0     1-2 билета         6120            2451     0.400490
# 1     2-3 билета        10091            7543     0.747498
# 2    3-5 билетов         5513            3497     0.634319
# 3     5+ билетов          209              68     0.325359

# %% [markdown]
#  - Как распределены пользователи по сегментам — равномерно или сконцентрировано?
#     - Есть ли сегменты с аномально высокой или низкой долей повторных покупок?
#  Сегмент «2–3 билета» является самым многочисленным и одновременно самым лояльным: доля повторных покупок здесь достигает 74.7%. > * Это говорит о том, что платформа успешно закрывает потребность в групповых покупках. Пользователи, нашедшие удобное решение для себя и близких, становятся постоянными клиентами.
#  Рекомендация: Сфокусировать усилия по удержанию именно на этом сегменте. Развивать функционал для групповых покупок (бронирование мест рядом, семейные пакеты, промокоды для друзей). Именно этот сегмент приносит основную массу повторных заказов.
#  Для сегмента «5+» лучше не создавать отдельные сложные механики, а просто обеспечить базовый комфорт (выбор мест).
#  Среднее количество билетов в заказе, в целом, связано с вероятностью повторного заказа и оптимальным диапазоном по удержанию действительно является группа "2–3 билета".

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Я бы также отметил, что скорее всего группа "5+ билетов" - это какие-то оптовые закупки или разовые групповые походы (школы, тургруппы), и для бизнеса важно понимать, что эти клиенты почти не возвращаются. Подводя итог, можно дополнить, что среднее количество билетов в заказе, в целом, связано с вероятностью повторного заказа и оптимальным диапазоном по удержанию действительно является группа "2–3 билета". Покажу и такой пример реализации здесь:
#
#     #создадим отдельный датафрейм для категоризации
#     ticket_count = df_1[['user_id','is_two','agv_count_tickets']].copy()
#     #категоризируем пользвателей
#     ticket_count['ticket_segment'] = pd.cut(ticket_count['agv_count_tickets'],bins=(1,2,3,5,float('inf')),labels=('1-2 билета','2-3 билета','3-5 билетов','5+ билетов'),right=False)
#     #сгруппируем пользвателей по категориям и посчитаем кол-во и долю вернувшихся пользователей
#     ticket_count = ticket_count.groupby('ticket_segment').agg(count =('user_id','count'),share_return = ('is_two','mean'))
#     ticket_count
#     #построим диаграмму для доли вернувшихся пользователей в разных категориях
#     ticket_count['share_return'].plot(kind='bar',color='lightgreen',figsize=(14,8),rot=1)
#     plt.title('Распределение доли возвратов пользователей по категориям')
#     plt.xlabel('')
#     plt.ylabel('Доля вернувшихся пользователей')
#     plt.grid(axis='y')
#     plt.show()

# %% [markdown]
# ---
#
# ####  Исследование временных характеристик первого заказа и их влияния на повторные покупки
#
# Изучите временные параметры, связанные с первым заказом пользователей:
#
# - день недели первой покупки;
# - время с момента первой покупки — лайфтайм;
# - средний интервал между покупками пользователей с повторными заказами.
#
# ---
#
# ##### Задача Проанализируйте, как день недели, в которой была совершена первая покупка, влияет на поведение пользователей.
#
# - По данным даты первого заказа выделите день недели.
# - Для каждого дня недели подсчитайте общее число пользователей и долю пользователей, совершивших повторные заказы. Результаты визуализируйте.
# - Ответьте на вопрос: влияет ли день недели, в которую совершена первая покупка, на вероятность возврата клиента?
#
# ---

# %%
# Считаем дату первого заказа для каждого пользователя
first_order_date = clean_df.groupby('user_id')['order_dt'].min().reset_index()
first_order_date.columns = ['user_id', 'first_order_date']

# соберём профиль пользователя.

user_profile = clean_df.groupby('user_id').agg(
    first_order_date=('order_dt', 'min'),
    total_orders=('order_id', 'nunique')
).reset_index()

# Добавляем флаг возврата: 1 если заказов >= 2, иначе 0
user_profile['returned'] = (user_profile['total_orders'] >= 2).astype(int)

print(user_profile.head())
# Out:
#            user_id first_order_date  total_orders  returned
# 0  0002849b70a3ce2       2024-08-20             1         0
# 1  0005ca5e93f2cf4       2024-07-23             2         1
# 2  000898990054619       2024-07-13             3         1
# 3  00096d1f542ab2b       2024-08-15             1         0
# 4  000a55a418c128c       2024-09-29             2         1

# %%
# Извлекаем день недели через .dt.day_name().

# Преобразуем в datetime
user_profile['first_order_date'] = pd.to_datetime(user_profile['first_order_date'])

# Получаем название дня недели 
user_profile['first_day_of_week'] = user_profile['first_order_date'].dt.day_name()

print(user_profile['first_day_of_week'].value_counts()) 
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
user_profile['first_day_of_week'] = pd.Categorical(user_profile['first_day_of_week'], 
                                                   categories=days_order,
                                                   ordered=True)
# Out:
# Saturday     3461
# Friday       3274
# Tuesday      3218
# Thursday     3130
# Wednesday    3084
# Monday       2947
# Sunday       2819
# Name: first_day_of_week, dtype: int64

# %%
# Считаем метрики по дням недели
#Теперь для каждого дня недели считаем: 
# Общее число пользователей, сделавших первый заказ в этот день. 
# Число вернувшихся пользователей среди них. 
# Долю возврата.

# Группируем по дню недели
day_analysis = user_profile.groupby('first_day_of_week').agg(
    total_users=('user_id', 'nunique'),
    returned_users=('returned', 'sum')
).reset_index()

# Считаем долю возврата
day_analysis['return_rate'] = day_analysis['returned_users'] / day_analysis['total_users']

# Сортируем по порядку дней (если задали категории выше, sort_index сработает правильно)
day_analysis = day_analysis.sort_values('first_day_of_week')

print(day_analysis)
# Out:
#   first_day_of_week  total_users  returned_users  return_rate
# 0            Monday         2947            1868     0.633865
# 1           Tuesday         3218            2010     0.624612
# 2         Wednesday         3084            1927     0.624838
# 3          Thursday         3130            1865     0.595847
# 4            Friday         3274            1962     0.599267
# 5          Saturday         3461            2219     0.641144
# 6            Sunday         2819            1708     0.605889

# %% [markdown]
# День недели первой покупки оказывает незначительное влияние на вероятность возврата.
# Доля повторных покупок варьируется в узком диапазоне от 59.6% (четверг) до 64.2% (суббота).
# Разница между крайними значениями составляет всего 4.6 п.п., что говорит об однородности поведения пользователей независимо от дня их первого заказа.
# Вывод: День недели не является ключевым драйвером лояльности. Стратегию удержания не стоит строить вокруг конкретного дня недели. Более важными факторами остаются тип мероприятия, размер заказа и удобство сервиса.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> В целом, все верно. Разница в долях действительно не очень велика. Предлагаю лишь перепроверить все значения еще раз после доработки

# %% [markdown]
# ---
#
# ##### Задача  Изучите, как средний интервал между заказами влияет на удержание клиентов.
#
# - Рассчитайте среднее время между заказами для двух групп пользователей:
#     - совершившие 2–4 заказа;
#     - совершившие 5 и более заказов.
# - Исследуйте, как средний интервал между заказами влияет на вероятность повторного заказа, и сделайте выводы.
#
# ---

# %%
# Считаем интервалы между заказами для каждого пользователя

df_for_intervals = clean_df[['user_id', 'order_dt']].copy()

# Сортируем по пользователю и дате (это критически важно!)
df_for_intervals = df_for_intervals.sort_values(['user_id', 'order_dt'])

# Считаем разницу между текущей и предыдущей датой для каждого пользователя
df_for_intervals['days_diff'] = df_for_intervals.groupby('user_id')['order_dt'].diff().dt.days

# %%
# Агрегируем данные до уровня пользователя
# Теперь для каждого пользователя считаем: 
#Сколько всего заказов (order_count). 
# Средний интервал между его заказами (avg_interval_days).

user_intervals = df_for_intervals.groupby('user_id').agg(
    order_count=('order_dt', 'count'),
    avg_interval_days=('days_diff', 'mean')  
).reset_index()

# Добавим флаг возврата (для контекста)
user_intervals['returned'] = (user_intervals['order_count'] >= 2).astype(int)

print(user_intervals.head())
# Out:
#            user_id  order_count  avg_interval_days  returned
# 0  0002849b70a3ce2            1                NaN         0
# 1  0005ca5e93f2cf4            2               75.0         1
# 2  000898990054619            3               51.0         1
# 3  00096d1f542ab2b            1                NaN         0
# 4  000a55a418c128c            2               16.0         1

# %%
# Разделяем на две группы (как в условии)
#Группа А: 2–4 заказа.
#Группа Б: 5+ заказов.

group_2_4 = user_intervals[(user_intervals['order_count'] >= 2) & (user_intervals['order_count'] <= 4)]
group_5_plus = user_intervals[user_intervals['order_count'] >= 5]

print(f"Группа 2-4 заказа: {len(group_2_4)} пользователей")
print(f"Группа 5+ заказов: {len(group_5_plus)} пользователей")
# Out:
# Группа 2-4 заказа: 7159 пользователей
# Группа 5+ заказов: 6400 пользователей

# %%
# Считаем средний интервал для каждой группы ---

mean_interval_2_4 = group_2_4['avg_interval_days'].mean()
mean_interval_5_plus = group_5_plus['avg_interval_days'].mean()

median_interval_2_4 = group_2_4['avg_interval_days'].median()
median_interval_5_plus = group_5_plus['avg_interval_days'].median()

std_interval_2_4 = group_2_4['avg_interval_days'].std()
std_interval_5_plus = group_5_plus['avg_interval_days'].std()

print("\n--- Результаты по среднему интервалу между заказами ---")
print(f"Группа 2–4 заказа: среднее = {mean_interval_2_4:.1f} дней, медиана = {median_interval_2_4:.1f} дней, стд. отклонение = {std_interval_2_4:.1f}")
print(f"Группа 5+ заказов: среднее = {mean_interval_5_plus:.1f} дней, медиана = {median_interval_5_plus:.1f} дней, стд. отклонение = {std_interval_5_plus:.1f}")
# Out:
# --- Результаты по среднему интервалу между заказами ---
# Группа 2–4 заказа: среднее = 21.3 дней, медиана = 9.0 дней, стд. отклонение = 28.6
# Группа 5+ заказов: среднее = 9.6 дней, медиана = 7.8 дней, стд. отклонение = 7.9

# %% [markdown]
# ВЫВОД
# Пользователи с 5+ заказами совершают покупки в среднем каждые 9.6 дней,  чем пользователи с 2–4 заказами (каждые 21.3 дня)». Короткий интервал между заказами — это надёжный индикатор высокой вовлечённости пользователя. Для задач удержания и прогнозирования оттока данный признак является одним из самых сильных: рост интервала между покупками (например, свыше 30 дней) может служить сигналом о риске потери клиента

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> По полученным результатам отмечаем, что чем больше заказов совершает пользователь, тем чаще он их делает — средний интервал между заказами у активных пользователей (5+) почти вдвое меньше, чем у пользователей с меньшим числом заказов. Это указывает на более высокую вовлечённость и регулярность покупок среди лояльных пользователей.

# %% [markdown]
#  ### Корреляционный анализ количества покупок и признаков пользователя
# Изучите, какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок. Для этого используйте универсальный коэффициент корреляции phi_k, который позволяет анализировать как числовые, так и категориальные признаки.
#
# #### Задача Проведите корреляционный анализ:
#
# Рассчитайте коэффициент корреляции phi_k между признаками профиля пользователя и числом заказов ( total_orders ). При необходимости используйте параметр interval_cols для определения интервальных данных.
# Проанализируйте полученные результаты. Если полученные значения будут близки к нулю, проверьте разброс данных в total_orders. Такое возможно, когда в данных преобладает одно значение: в таком случае корреляционный анализ может показать отсутствие связей. Чтобы этого избежать, выделите сегменты пользователей по полю total_orders, а затем повторите корреляционный анализ. Выделите такие сегменты:
#
# 1 заказ;
#
# от 2 до 4 заказов;
#
# от 5 и выше.
#
# Визуализируйте результат корреляции с помощью тепловой карты.
# Ответьте на вопрос: какие признаки наиболее связаны с количеством заказов?

# %%
print(total_orders_clean.columns)
# Out:
# Index(['user_id', 'first_order_dt', 'last_order_dt', 'first_device',
#        'first_region_name', 'first_service_name', 'first_event_type',
#        'total_orders', 'avg_revenue_rub', 'avg_tickets_count',
#        'avg_days_between_orders', 'is_two', 'is_five'],
#       dtype='object')

# %%
import phik
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Функция сегментации (она у тебя была верной)
def segment_orders(x):
    if x == 1:
        return '1 заказ'
    elif 2 <= x <= 4:
        return '2-4 заказа'
    else:
        return '5+ заказов'

# 2. ВАЖНО: Работаем только с total_orders_clean!
# Создаем сегмент прямо в нем.
# Берем колонку 'total_orders' (именно так она называется в списке колонок!)
total_orders_clean['orders_segment'] = total_orders_clean['total_orders'].apply(segment_orders)

print("Сегменты созданы в total_orders_clean!")
print(total_orders_clean['orders_segment'].value_counts())

# 3. Список колонок для анализа
# Убедись, что все эти названия точно есть в total_orders_clean.columns
cols_to_analyze = [
    'first_order_dt', 'last_order_dt', 'first_device',
    'first_region_name', 'first_service_name', 'first_event_type',
    'avg_revenue_rub', 'avg_tickets_count',
    'avg_days_between_orders', 
    'orders_segment'  # Наша новая колонка
]

# 4. Считаем матрицу корреляций
# Передаем total_orders_clean, так как мы только что добавили туда orders_segment
correlation_matrix = phik.phik_matrix(
    total_orders_clean[cols_to_analyze], 
    interval_cols=['avg_revenue_rub', 'avg_tickets_count', 'avg_days_between_orders']
)

print("\n Матрица корреляций Phi_K:")
print(correlation_matrix)

# 5. Визуализация
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=.5)
plt.title('Корреляция Phi_K между признаками и сегментом лояльности', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Сегменты созданы в total_orders_clean!
# 1 заказ       8374
# 2-4 заказа    7159
# 5+ заказов    6181
# Name: orders_segment, dtype: int64
#
#  Матрица корреляций Phi_K:
#                          first_order_dt  last_order_dt  first_device  \
# first_order_dt                 1.000000       0.998804      0.107270
# last_order_dt                  0.998804       1.000000      0.082683
# first_device                   0.107270       0.082683      1.000000
# first_region_name              0.483127       0.353890      0.116445
# first_service_name             0.295208       0.222441      0.084216
# first_event_type               0.264372       0.165444      0.062440
# avg_revenue_rub                0.226931       0.401619      0.033504
# avg_tickets_count              0.246717       0.231330      0.058329
# avg_days_between_orders        0.330849       0.188986      0.024605
# orders_segment                 0.578529       0.605296      0.017273
#
# ...

# %%
# Группируем данные и смотрим среднее количество дней между заказами в каждом сегменте
segmentation_stats = total_orders_clean.groupby('orders_segment')['avg_days_between_orders'].agg(['mean', 'count'])
print(segmentation_stats)

# Визуализация: должно быть видно, что в сегменте "5+ заказов" среднее значение дней меньше
plt.figure(figsize=(10, 6))
sns.boxplot(data=total_orders_clean, x='orders_segment', y='avg_days_between_orders')
plt.title('Распределение дней между заказами по сегментам лояльности')
plt.xlabel('Сегмент количества заказов')
plt.ylabel('Среднее кол-во дней между заказами')
plt.show()
# Out:
#                      mean  count
# orders_segment
# 1 заказ               NaN      0
# 2-4 заказа      21.047120   7159
# 5+ заказов       9.680931   6181

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Все пипы и импорты должны собирать в начале тетрадки, как этого от нас и требует PEP8

# %% [markdown]
# В ходе анализа целевой переменной (сегментация пользователей по количеству заказов: "1 заказ", "2–4 заказа", "5+ заказов") с помощью коэффициента корреляции Phi_K были получены следующие результаты:
#
# Сильная связь с датами (first_order_dt и last_order_dt):
# 0.578 и 0.605 — это умеренно-сильная корреляция.
# Что это значит: Лояльные пользователи (сегмент «5+ заказов») действительно отличаются по времени активности. Они либо давно с нами (большая давность первого заказа), либо делают заказы стабильно долго (большой промежуток между первым и последним). Для бизнеса это сигнал: «старые» клиенты чаще становятся лояльными.
#
# Главный драйвер — частота покупок (avg_days_between_orders):
# Корреляция 0.465 — это очень хороший результат для категориального признака!
# Что это значит: Это прямое подтверждение твоей гипотезы. Чем чаще человек покупает (меньше дней между заказами), тем выше вероятность, что он попадет в сегмент «5+ заказов». Это самый мощный предиктор для будущей модели.
#
# Связь с выручкой и билетами (avg_tickets_count):
# Корреляция 0.405 с количеством билетов.
# Что это значит: Пользователи, которые берут много билетов за раз (или в среднем), чаще становятся лояльными. Это логично: если человек купил сразу пачку билетов на разные события, он уже сильно вовлечен.
#
# Слабые связи (и это тоже хорошо!):
# first_device: корреляция всего 0.017.
# first_region_name: корреляция 0.124.
# Что это значит: Тип устройства и регион проживания не являются определяющими факторами лояльности. Неважно, с телефона или ПК человек делает заказ, и не так важно, из какого он города — поведение формируется другими факторами (частотой, вовлеченностью). Это позволяет не усложнять модель лишними признаками.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Елизавета, похвально, что здесь используешь именно phi_k, но я не совсем согласен с параметрами, которые мы здесь анализируем и interval_cols, которые также необходимо выбрать. Я предложил бы здесь подобный вариант:
#
#     correlation_matrix = profiles[['first_order_device', 'first_order_region', 'first_order_service',
#                          'first_order_genre', 'day_number',
#                          'avg_revenue_rub', 'agv_count_tickets', 'avg_order_interval',
#                          'orders_segment']].phik_matrix(
#     interval_cols=['avg_revenue_rub', 'agv_count_tickets', 'avg_order_interval']
#     )
#
# Так, интерпретировать связи между признаками профиля пользователя и количеством заказов получится проще

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Теперь я с тобой согласен, Елизавета! Сильная связь с сегментами по количеству покупок действительно наблюдается у временных показателей — среднего времени между покупками, а также сегмента по количеству билетов. Также заметна умеренная связь с средней выручкой

# %% [markdown]
# ### 5. Общий вывод и рекомендации
#
# В конце проекта напишите общий вывод и рекомендации: расскажите заказчику, на что нужно обратить внимание. В выводах кратко укажите:
#
# - **Информацию о данных**, с которыми вы работали, и то, как они были подготовлены: например, расскажите о фильтрации данных, переводе тенге в рубли, фильтрации выбросов.
# - **Основные результаты анализа.** Например, укажите:
#     - Сколько пользователей в выборке? Как распределены пользователи по числу заказов? Какие ещё статистические показатели вы подсчитали важным во время изучения данных?
#     - Какие признаки первого заказа связаны с возвратом пользователей?
#     - Как связаны средняя выручка и количество билетов в заказе с вероятностью повторных покупок?
#     - Какие временные характеристики влияют на удержание (день недели, интервалы между покупками)?
#     - Какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок согласно результатам корреляционного анализа?
# - Дополните выводы информацией, которая покажется вам важной и интересной. Следите за общим объёмом выводов — они должны быть компактными и ёмкими.
#
# В конце предложите заказчику рекомендации о том, как именно действовать в его ситуации. Например, укажите, на какие сегменты пользователей стоит обратить внимание в первую очередь, а какие нуждаются в дополнительных маркетинговых усилиях.

# %%
# Дополнительные расчеты данных для выводов
# Доля пользователей с РОВНО 1 заказом (это твоя первая цифра, она верна)
share_1 = (user_profile['total_orders'] == 1).mean() * 100

# 2. Доля пользователей с 2–4 заказами (НЕ ровно 2, а от 2 до 4 включительно)
share_2_4 = ((user_profile['total_orders'] >= 2) & (user_profile['total_orders'] <= 4)).mean() * 100

# 3. Доля пользователей с 5+ заказами (НЕ ровно 5, а 5 и выше)
share_5_plus = (user_profile['total_orders'] >= 5).mean() * 100

print(f"Доля сегмента '1 заказ': {share_1:.2f}%")
print(f"Доля сегмента '2-4 заказа': {share_2_4:.2f}%")
print(f"Доля сегмента '5+ заказов': {share_5_plus:.2f}%")
# Out:
# Доля сегмента '1 заказ': 38.18%
# Доля сегмента '2-4 заказа': 32.64%
# Доля сегмента '5+ заказов': 29.18%

# %% [markdown]
# 1.Общая характеристика выборки и распределение пользователей Для анализа поведения пользователей была выполнена агрегация на уровне пользователя (user_id), получено 290 611 заказов. Сформирована таблица профилей пользователей и составила: 21 933 уникальных пользователей со Средней выручкой с одного заказа: 625.58, это пользователи совершившие:
#
# 2+ заказов: 13559 (61.82%);
# 5+ заказами: 6400 (29.18%); после отсечения аномальных пользователей по 99 перцентилю в количестве 219 пользователей осталось: 21714 пользователя:
# 2+ заказов: 13340 (61.44%)
# 5+ заказами: 6181 (28.47%)
#
# - Среднее количество заказов на одного пользователя в выборке составляет ~13.5. Это указывает на то, что анализируемая когорта состоит преимущественно из активных и лояльных пользователей, чьи данные охватывают длительный период работы платформы.
# - Распределение пользователей по уровню лояльности: * 38.16% — совершили только 1 заказ (потенциал для удержания). * 32.64% — сегмент умеренной лояльности (2–4 заказа). * 29.20% — ядро лояльной аудитории (5+ заказов).
# Вывод: В отличие от типичных срезов, где доля оттока превышает 60–70%, в данной когорте наблюдается зрелая структура аудитории. Высокая доля пользователей с 5+ заказами (29.2%) подтверждает эффективность платформы в удержании клиентов в долгосрочной перспективе. Однако сегмент «1 заказ» остаётся зоной роста, так как даже в такой лояльной выборке он составляет почти две пятых всей аудитории.»
# Статистическими показателями, характеризующими поведение аудитории, стали:
# - по количеству билетов в заказе: 3 шт. (медиана: 2), что говорит о преобладании одиночных и парных покупок.
# - по числу заказов на пользователя от 2 до 13, (после очистки от пользоватей совершавших крупные заказы 152 пользователя)
# - по среднему количеству дней между покупками от 8 до 15
# - средняя выручка с заказа: 625.58 руб.
# - Средний возврат пользователей по всей выборке: 61.4%.
# Порог отсечения (99-й перцентиль): 152.0 заказов
# Всего уникальных пользователей: 21933
# Пользователей-аномалий (выше порога): 219
# Доля аномалий среди пользователей: 1.00%
# Потеряно заказов из-за фильтрации: 148999 (51.27%)
#
#  2. Признаки первого заказа, связанные с возвратом (Гипотеза 1) „Пользователи, купившие первый билет на спорт, возвращаются чаще, чем те, кто начал с концертов“. Результаты подтвердили это предположение: доля повторных покупок среди пользователей, чей первый заказ был на спортивное мероприятие, составила 86,15%, тогда как среди тех, кто начинал с концертов, этот показатель равен 72,81%
#  Таким образом, сегмент „Спорт“ можно считать более эффективным „каналом удержания“: попадание пользователя в эту категорию на старте повышает шансы на то, что он станет постоянным клиентом платформы».
#  ВЫВОД из количества пользователей: 21714
#
# Тип мероприятия: есть явные «точки входа» концерты 9616 44.28% другое 5425 24.98% театр 4262 19.63%
#
#  3.Есть ли сегменты с аномально высокой или низкой долей повторных покупок? Сегмент «2–3 билета» является самым многочисленным и одновременно самым лояльным: доля повторных покупок здесь достигает 74.7%. > * Это говорит о том, что платформа успешно закрывает потребность в групповых покупках. Пользователи, нашедшие удобное решение для себя и близких, становятся постоянными клиентами. Рекомендация: Сфокусировать усилия по удержанию именно на этом сегменте. Развивать функционал для групповых покупок (бронирование мест рядом, семейные пакеты, промокоды для друзей). Именно этот сегмент приносит основную массу повторных заказов. Для сегмента «5+» лучше не создавать отдельные сложные механики, а просто обеспечить базовый комфорт (выбор мест). Среднее количество билетов в заказе, в целом, связано с вероятностью повторного заказа и оптимальным диапазоном по удержанию действительно является группа "2–3 билета".
#
# 4. Временные характеристики. День недели первой покупки оказывает незначительное влияние на вероятность возврата. Доля повторных покупок варьируется в узком диапазоне от 59.6% (четверг) до 64.2% (суббота). Разница между крайними значениями составляет всего 4.6 п.п., что говорит об однородности поведения пользователей независимо от дня их первого заказа. Вывод: День недели не является ключевым драйвером лояльности. Стратегию удержания не стоит строить вокруг конкретного дня недели. Более важными факторами остаются тип мероприятия, размер заказа и удобство сервиса.
#
# 5. Для стимулирования перехода пользователей в сегмент «5+ заказов» необходимо внедрять механики, сокращающие интервал между покупками (напоминания, персональные подборки, подписки). Поскольку avg_days_between_orders является сильнейшим предиктором лояльности (корреляция 0.47), необходимо автоматизировать работу с этим показателем.
#
# * Для сегмента «1 заказ»: Запускать реактивационные цепочки (email/push) через 7–14 дней после первой покупки с предложением скидки или подборки событий. Цель — сократить интервал до второго заказа.
#
# * Для сегмента «2–4 заказа»: Предлагать программы лояльности или накопительные бонусы, чтобы мотивировать пользователя совершить 5-й заказ и перейти в категорию «лояльных».
#
# * Для сегмента «5+ заказов»: Использовать стратегию удержания. Отслеживать увеличение avg_days_between_orders у этих пользователей: если интервал начинает расти, это сигнал риска оттока. Нужно предлагать персональные подборки или ранний доступ к билетам.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Елизавета, похвально, что не забываешь о важности представления итогового вывода по проекту, в котором ты отражаешь основные пункты, перечисленные в задании. Предлагаю его еще раз перепроверить и скорректировать. В целом, структура здесь подходящая:
#
# 1. Информация о данных: Ты описала исходный объем, конвертацию тенге в рубли, а также ключевые этапы подготовки данных: фильтрацию выбросов по 99-му перцентилю и исключение нулевых значений.
#
# 2. Основные статистические показатели: Указано общее количество пользователей, неравномерное распределение по числу заказов.
#
# 3. Признаки первого заказа: Верно отмечено, что на лояльность влияют количество билетов, тип мероприятия, устройство, регион и оператор.
#
# 4. Билеты в заказе: Точно названа аномалия - пользователи, покупающие 2-3 билета, самые лояльные, а пользователи с 5+ билетами имеют аномально низкий возврат.
#
# 5. Временные характеристики: Установлено, что день недели практически не оказывает влияет на удержание, а интервалы между покупками влияют существенно, что является одним из главных выводов.
#
# Предложенные рекомендации логически вытекают из результатов анализа. Всегда стоит делать упор на указание широкого пула возможных стратегий повышения выручки. По моему опыту, для многих руководителей важно умение аналитика давать всеохватывающие и в то же время конкретные предложения.
#
# Итоговые выводы - важная часть работы и в твоих будущих реальных проектах советую уделять ей особое внимание. Бывают ситуации, когда у руководства нет времени вникать в весь проект и оценка твоих действий будет проводиться именно по ним.
#
# Подводя итог, ты приложила много усилий, молодец. Работа выполнена очень качественно. Осталось лишь проработать несколько аспектов, которые я отметил при проверке, а для того, чтобы тебе было проще, я постарался оставить комментарии по каждому интересующему нас моменту. Уверен, что у тебя все получится!
#
# **Желаю успехов и жду твой проект на повторное ревью, Елизавета!**

# %% [markdown]
# ### 6. Финализация проекта и публикация в Git
#
# Когда вы закончите анализировать данные, оформите проект, а затем опубликуйте его.
#
# Выполните следующие действия:
#
# 1. Создайте файл `.gitignore`. Добавьте в него все временные и чувствительные файлы, которые не должны попасть в репозиторий.
# 2. Сформируйте файл `requirements.txt`. Зафиксируйте все библиотеки, которые вы использовали в проекте.
# 3. Вынести все чувствительные данные (параметры подключения к базе) в `.env`файл.
# 4. Проверьте, что проект запускается и воспроизводим.
# 5. Загрузите проект в публичный репозиторий — например, на GitHub. Убедитесь, что все нужные файлы находятся в репозитории, исключая те, что в `.gitignore`. Ссылка на репозиторий понадобится для отправки проекта на проверку. Вставьте её в шаблон проекта в тетрадке Jupyter Notebook перед отправкой проекта на ревью.

# %% [markdown]
# **Вставьте ссылку на проект в этой ячейке тетрадки перед отправкой проекта на ревью.**

# %% [markdown]
# https://github.com/Lizbet-Lit/Afisha_project

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> GitHub с проектом оформлен корректно: отлично, что есть файл `.gitignore`

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Стоит добавить также файл `README.md`, в котором можно также дать небольшое описание проекта и оставить итоговый вывод для наглядности
